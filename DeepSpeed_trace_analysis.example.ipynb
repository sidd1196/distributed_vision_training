# %% [markdown]
# ## HTA analysis

# %%
import zipfile
import os


# 1. using path for the tracer logs saved
ZIP_SOURCE_PATH = "/content/drive/MyDrive/MSML_610/profiler_trace_files"

# 2. Where to extract them for HTA (Keep this consistent)
ANALYSIS_OUTPUT_PATH = "./hta_analysis"

# %%
# Verify source exists
if not os.path.exists(ZIP_SOURCE_PATH):
    print(f"Error: The source path '{ZIP_SOURCE_PATH}' does not exist.")
else:
    # Find zip files in that specific folder
    zip_files = [f for f in os.listdir(ZIP_SOURCE_PATH) if f.endswith('.zip')]

    if not zip_files:
        print(f" No .zip files found inside {ZIP_SOURCE_PATH}")
    else:
        print(f" Found {len(zip_files)} zip files.")

        for zf in zip_files:
            # Full path to the zip file
            full_zip_path = os.path.join(ZIP_SOURCE_PATH, zf)

            # Create a specific folder for this run in the analysis directory
            # e.g., stage2_trace.zip -> ./hta_analysis/stage2_trace/
            folder_name = zf.replace(".zip", "")
            extract_path = os.path.join(ANALYSIS_OUTPUT_PATH, folder_name)

            print(f"   extracting: {zf} \n  -> to: {extract_path}")

            try:
                with zipfile.ZipFile(full_zip_path, 'r') as zip_ref:
                    zip_ref.extractall(extract_path)
            except zipfile.BadZipFile:
                print(f"Error: {zf} is corrupt.")

        print("\n--- FINAL FOLDER STRUCTURE FOR HTA ---")
        for root, dirs, files in os.walk(ANALYSIS_OUTPUT_PATH):
            level = root.replace(ANALYSIS_OUTPUT_PATH, '').count(os.sep)
            indent = ' ' * 4 * (level)
            print(f"{indent}{os.path.basename(root)}/")
            for f in files:
                if f.endswith('.json') or f.endswith('.gz'):
                    print(f"{indent}    {f}")
# Out:
#  Found 3 zip files.
#    extracting: deepspeed_stage2_trace.zip
#   -> to: ./hta_analysis/deepspeed_stage2_trace
#    extracting: deepspeed_stage3_trace.zip
#   -> to: ./hta_analysis/deepspeed_stage3_trace
#    extracting: deepspeed_zeropp_trace.zip
#   -> to: ./hta_analysis/deepspeed_zeropp_trace
#
# --- FINAL FOLDER STRUCTURE FOR HTA ---
# hta_analysis/
#     deepspeed_stage2_trace/
#         __MACOSX/
#             deepspeed_stage2_trace/
#                 ._e9b764cef546_490.1764732007835768228.pt.trace.json
#                 ._e9b764cef546_491.1764732007918481049.pt.trace.json
#                 ._merged_multi_gpu_trace.json
#         deepspeed_stage2_trace/
#             merged_multi_gpu_trace.json
#             e9b764cef546_491.1764732007918481049.pt.trace.json
#             e9b764cef546_490.1764732007835768228.pt.trace.json
#     deepspeed_zeropp_trace/
#         __MACOSX/
#             deepspeed_zeropp_trace/
#                 ._e9b764cef546_1636.1764734345842034861.pt.trace.json
#                 ._e9b764cef546_1635.1764734346073085690.pt.trace.json
#         deepspeed_zeropp_trace/
#             e9b764cef546_1636.1764734345842034861.pt.trace.json
#             e9b764cef546_1635.1764734346073085690.pt.trace.json
#     deepspeed_stage3_trace/
#         __MACOSX/
#             deepspeed_stage3_trace/
#                 ._e9b764cef546_841.1764733329627368586.pt.trace.json
#                 ._e9b764cef546_842.1764733329119935387.pt.trace.json
#         deepspeed_stage3_trace/
#             e9b764cef546_842.1764733329119935387.pt.trace.json
#             e9b764cef546_841.1764733329627368586.pt.trace.json

# %%
# !pip3 install hta
# !pip install HolisticTraceAnalysis
# Out:
# Collecting hta
#   Downloading hta-0.1.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from hta) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from hta) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from hta) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from hta) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->hta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->hta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->hta) (1.17.0)
# Downloading hta-0.1.0-py3-none-any.whl (16 kB)
# Installing collected packages: hta
# Successfully installed hta-0.1.0
# Collecting HolisticTraceAnalysis
#   Downloading holistictraceanalysis-0.5.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting jupyterlab>=3.5.1 (from HolisticTraceAnalysis)
#   Downloading jupyterlab-4.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from HolisticTraceAnalysis) (2.0.2)
# Requirement already satisfied: networkx>=3.1 in /usr/local/lib/python3.12/dist-packages (from HolisticTraceAnalysis) (3.6.1)
# Requirement already satisfied: pandas>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from HolisticTraceAnalysis) (2.2.2)
# Requirement already satisfied: plotly>=5.11.0 in /usr/local/lib/python3.12/dist-packages (from HolisticTraceAnalysis) (5.24.1)
# Requirement already satisfied: pydot>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from HolisticTraceAnalysis) (4.0.1)
# Requirement already satisfied: pytest>=7.4.4 in /usr/local/lib/python3.12/dist-packages (from HolisticTraceAnalysis) (8.4.2)
# Collecting async-lru>=1.0.0 (from jupyterlab>=3.5.1->HolisticTraceAnalysis)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (6.17.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (3.1.6)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (5.9.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab>=3.5.1->HolisticTraceAnalysis)
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab>=3.5.1->HolisticTraceAnalysis)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.2.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (75.2.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (6.5.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=3.5.1->HolisticTraceAnalysis) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.2->HolisticTraceAnalysis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.2->HolisticTraceAnalysis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.2->HolisticTraceAnalysis) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.11.0->HolisticTraceAnalysis) (9.1.2)
# Requirement already satisfied: pyparsing>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pydot>=1.3.0->HolisticTraceAnalysis) (3.2.5)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4.4->HolisticTraceAnalysis) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4.4->HolisticTraceAnalysis) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4.4->HolisticTraceAnalysis) (2.19.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.16.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (26.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->jupyterlab>=3.5.1->HolisticTraceAnalysis) (3.0.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.5.1)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis)
#   Downloading json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.2->HolisticTraceAnalysis) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.25.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (25.1.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.5.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.8.5)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (25.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (0.2.14)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.5.1->HolisticTraceAnalysis) (1.4.0)
# Downloading holistictraceanalysis-0.5.0-py3-none-any.whl (371 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.2/371.2 kB 10.1 MB/s eta 0:00:00
# Downloading jupyterlab-4.5.0-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 56.8 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 5.4 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.4 MB/s eta 0:00:00
# Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.8 MB/s eta 0:00:00
# Installing collected packages: json5, jedi, async-lru, jupyterlab-server, jupyter-lsp, jupyterlab, HolisticTraceAnalysis
# Successfully installed HolisticTraceAnalysis-0.5.0 async-lru-2.0.5 jedi-0.19.2 json5-0.12.1 jupyter-lsp-2.3.0 jupyterlab-4.5.0 jupyterlab-server-2.28.0

# %% [markdown]
# ## Analysing all the trace files from the multi gpu runs using HTA

# %%
from hta.trace_analysis import TraceAnalysis
import os
import glob
import json
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Ensure plots display inline in Jupyter
# %matplotlib inline

# --- CONFIGURATION ---
source_traces = {
    "Stage 2": "./hta_analysis/deepspeed_stage2_trace/deepspeed_stage2_trace",
    "Stage 3": "./hta_analysis/deepspeed_stage3_trace/deepspeed_stage3_trace",
    "ZeRO++": "./hta_analysis/deepspeed_zeropp_trace/deepspeed_zeropp_trace"
}

FAST_DIR_BASE = "./hta_analysis/fast_slices"
TARGET_STEP = 3

# Set plot style for better visibility
sns.set_theme(style="whitegrid")

# --- HELPER: SLICER FUNCTION ---
def create_fast_slice(src_dir, stage_name):
    """Reads a huge trace, extracts ONE step, saves to a new folder."""
    output_dir = os.path.join(FAST_DIR_BASE, stage_name.replace(" ", "_"))
    os.makedirs(output_dir, exist_ok=True)

    print(f"  Slicing '{stage_name}'...")

    files = [f for f in glob.glob(os.path.join(src_dir, "*.json"))
             if "merged" not in f and not os.path.basename(f).startswith("._")]

    if not files:
        print(f"   No files found in {src_dir}")
        return None

    # Find time window
    start_ts, end_ts = 0, 0
    try:
        with open(files[0], 'r') as f:
            data = json.load(f)
            events = data.get("traceEvents", [])
            for e in events:
                if f"Step {TARGET_STEP}" in e.get("name", ""):
                    start_ts = e["ts"]
                    end_ts = start_ts + e["dur"]
                    break
    except:
        pass

    # Fallback if step not found
    if start_ts == 0:
        with open(files[0], 'r') as f:
            data = json.load(f)
            start_ts = data.get("traceEvents", [])[0]["ts"]
            end_ts = start_ts + 2_000_000

    # Slice files
    for t_file in files:
        out_path = os.path.join(output_dir, os.path.basename(t_file))
        if os.path.exists(out_path): continue

        try:
            with open(t_file, 'r') as f:
                data = json.load(f)
            sliced = [e for e in data["traceEvents"] if "ts" in e and start_ts <= e["ts"] <= end_ts]
            data["traceEvents"] = sliced
            with open(out_path, 'w') as f:
                json.dump(data, f)
            del data, sliced
            gc.collect()
        except Exception:
            pass

    return output_dir

# --- HELPER: INLINE PLOTTING FUNCTION ---
def show_inline_plots(analyzer, stage_name):
    """Extracts data and uses Matplotlib to show plots directly in the notebook output."""

    # 1. Temporal Breakdown
    try:
        print(f"\nTemp oral Breakdown: {stage_name}")
        # Get raw data (Pandas DataFrame)
        temp_df = analyzer.get_temporal_breakdown(visualize=False)

        # Create Plot
        plt.figure(figsize=(12, 6))
        # Plot directly from the DataFrame
        temp_df.plot(kind='bar', stacked=True, width=0.8, colormap='viridis', figsize=(12, 6), ax=plt.gca())

        plt.title(f"Temporal Breakdown - {stage_name}")
        plt.xlabel("GPU Rank")
        plt.ylabel("Time Proportion")
        plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)
        plt.show() # <--- Renders plot here in the notebook

    except Exception as e:
        print(f"      Could not generate Temporal Breakdown: {e}")

    # 2. Communication vs Computation Overlap
    try:
        print(f"\n Comm/Comp Overlap: {stage_name}")
        # Get raw data (Pandas DataFrame)
        overlap_df = analyzer.get_comm_comp_overlap(visualize=False)

        # Create Plot
        plt.figure(figsize=(12, 6))
        overlap_df.plot(kind='bar', stacked=True, width=0.8, colormap='coolwarm', figsize=(12, 6), ax=plt.gca())

        plt.title(f"Comm/Comp Overlap - {stage_name}")
        plt.xlabel("GPU Rank")
        plt.ylabel("Percentage")
        plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)
        plt.show() # <--- Renders plot here in the notebook

    except Exception as e:
        print(f"      Could not generate Overlap Analysis: {e}")

# --- MAIN LOOP ---
print("--- STARTING ANALYSIS ---")

for name, path in source_traces.items():
    if not os.path.exists(path):
        continue

    # Slice first
    analysis_target_path = create_fast_slice(path, name)
    if not analysis_target_path: continue

    # Analyze
    print(f"\n{'='*20} {name} {'='*20}")
    try:
        analyzer = TraceAnalysis(trace_dir=analysis_target_path)
        show_inline_plots(analyzer, name)
    except Exception as e:
        print(f"Analysis failed for {name}: {e}")
# Out:
# --- STARTING ANALYSIS ---
#   Slicing 'Stage 2'...
#
# ==================== Stage 2 ====================
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_2/e9b764cef546_490.1764732007835768228.pt.trace.json time = 0.84 seconds
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_2/e9b764cef546_491.1764732007918481049.pt.trace.json time = 0.84 seconds
# WARNING:hta:Rounding down ns resolution events due to issue with events overlapping. ts dtype = float64, dur dtype = float64.Please see https://github.com/pytorch/pytorch/pull/122425
# WARNING:hta:Rounding down ns resolution events due to issue with events overlapping. ts dtype = float64, dur dtype = float64.Please see https://github.com/pytorch/pytorch/pull/122425
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_2/e9b764cef546_490.1764732007835768228.pt.trace.json backend=ParserBackend.JSON in 3.03 seconds; current PID:3631
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_2/e9b764cef546_491.1764732007918481049.pt.trace.json backend=ParserBackend.JSON in 3.06 seconds; current PID:3632
# WARNING:hta:Overall parsing of /content/hta_analysis/fast_slices/Stage_2/e9b764cef546_490.1764732007835768228.pt.trace.json in 3.36 seconds; current PID:3631
# WARNING:hta:Overall parsing of /content/hta_analysis/fast_slices/Stage_2/e9b764cef546_491.1764732007918481049.pt.trace.json in 3.40 seconds; current PID:3632
# WARNING:hta:leaving parse_multiple_ranks duration=4.04 seconds
# WARNING:hta:leaving parse_traces duration=4.04 seconds
# WARNING:hta:There is only one iteration in the trace. The analysis result may not be accurate.
# Temp oral Breakdown: Stage 2
#  Comm/Comp Overlap: Stage 2
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:56: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comm_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:59: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comp_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:56: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comm_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:59: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comp_kernels.melt(var_name="status", value_name="time").replace(
#   Slicing 'Stage 3'...
#
# ==================== Stage 3 ====================
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_3/e9b764cef546_841.1764733329627368586.pt.trace.json time = 5.36 seconds
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_3/e9b764cef546_842.1764733329119935387.pt.trace.json time = 5.36 seconds
# WARNING:hta:Rounding down ns resolution events due to issue with events overlapping. ts dtype = float64, dur dtype = float64.Please see https://github.com/pytorch/pytorch/pull/122425
# WARNING:hta:Rounding down ns resolution events due to issue with events overlapping. ts dtype = float64, dur dtype = float64.Please see https://github.com/pytorch/pytorch/pull/122425
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_3/e9b764cef546_841.1764733329627368586.pt.trace.json backend=ParserBackend.JSON in 25.36 seconds; current PID:4256
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/Stage_3/e9b764cef546_842.1764733329119935387.pt.trace.json backend=ParserBackend.JSON in 25.39 seconds; current PID:4257
# WARNING:hta:Overall parsing of /content/hta_analysis/fast_slices/Stage_3/e9b764cef546_841.1764733329627368586.pt.trace.json in 27.63 seconds; current PID:4256
# WARNING:hta:Overall parsing of /content/hta_analysis/fast_slices/Stage_3/e9b764cef546_842.1764733329119935387.pt.trace.json in 27.97 seconds; current PID:4257
# WARNING:hta:leaving parse_multiple_ranks duration=31.45 seconds
# WARNING:hta:leaving parse_traces duration=31.45 seconds
# WARNING:hta:There is only one iteration in the trace. The analysis result may not be accurate.
# Temp oral Breakdown: Stage 3
#  Comm/Comp Overlap: Stage 3
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:56: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comm_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:59: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comp_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:56: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comm_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:59: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comp_kernels.melt(var_name="status", value_name="time").replace(
#   Slicing 'ZeRO++'...
#
# ==================== ZeRO++ ====================
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/ZeRO++/e9b764cef546_1636.1764734345842034861.pt.trace.json time = 5.40 seconds
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/ZeRO++/e9b764cef546_1635.1764734346073085690.pt.trace.json time = 5.41 seconds
# WARNING:hta:Rounding down ns resolution events due to issue with events overlapping. ts dtype = float64, dur dtype = float64.Please see https://github.com/pytorch/pytorch/pull/122425
# WARNING:hta:Rounding down ns resolution events due to issue with events overlapping. ts dtype = float64, dur dtype = float64.Please see https://github.com/pytorch/pytorch/pull/122425
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/ZeRO++/e9b764cef546_1636.1764734345842034861.pt.trace.json backend=ParserBackend.JSON in 25.40 seconds; current PID:4965
# WARNING:hta:Parsed /content/hta_analysis/fast_slices/ZeRO++/e9b764cef546_1635.1764734346073085690.pt.trace.json backend=ParserBackend.JSON in 25.41 seconds; current PID:4964
# WARNING:hta:Overall parsing of /content/hta_analysis/fast_slices/ZeRO++/e9b764cef546_1635.1764734346073085690.pt.trace.json in 27.70 seconds; current PID:4964
# WARNING:hta:Overall parsing of /content/hta_analysis/fast_slices/ZeRO++/e9b764cef546_1636.1764734345842034861.pt.trace.json in 28.00 seconds; current PID:4965
# WARNING:hta:leaving parse_multiple_ranks duration=31.44 seconds
# WARNING:hta:leaving parse_traces duration=31.44 seconds
# WARNING:hta:There is only one iteration in the trace. The analysis result may not be accurate.
# Temp oral Breakdown: ZeRO++
#  Comm/Comp Overlap: ZeRO++
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:56: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comm_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:59: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comp_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:56: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comm_kernels.melt(var_name="status", value_name="time").replace(
# /usr/local/lib/python3.12/dist-packages/hta/analyzers/communication_analysis.py:59: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   comp_kernels.melt(var_name="status", value_name="time").replace(
