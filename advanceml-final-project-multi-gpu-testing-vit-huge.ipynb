# %% [markdown]
# # Efficient Adaptation and Analysis of Vision Transformers

# %%
import torch
import sys

print("=== PyTorch Environment Test ===")
print(f"Python version: {sys.version}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")

    # Test GPU tensor
    x = torch.randn(3, 3).cuda()
    print(f"\nGPU tensor created: {x.device}")
    print(f"Tensor shape: {x.shape}")
else:
    print("CUDA not available - using CPU")
    x = torch.randn(3, 3)
    print(f"CPU tensor created: {x.device}")

print("\n✅ PyTorch test completed!")
# Out:
# === PyTorch Environment Test ===
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# CUDA version: 12.4
# Number of GPUs: 2
# GPU name: Tesla T4
#
# GPU tensor created: cuda:0
# Tensor shape: torch.Size([3, 3])
#
# ✅ PyTorch test completed!

# %%
# !nvidia-smi
# Out:
# Sun Nov 30 18:39:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0             26W /   70W |     105MiB /  15360MiB |      3%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   44C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install wandb
# !wandb login

import wandb
from kaggle_secrets import UserSecretsClient

# Get the secret value
user_secrets = UserSecretsClient()
wandb_api_key = user_secrets.get_secret("WANDB_API_KEY")

# Log in using the key
wandb.login(key=wandb_api_key)

print("✅ Successfully logged into W&B!")
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.21.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (6.33.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.33.2)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: siddpath (siddpath-university-of-maryland) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# ✅ Successfully logged into W&B!

# %% [markdown]
# #### Downloading the data

# %%
import torchvision
import torchvision.transforms as transforms

# Define a transform to normalize the data
# You'll likely want to resize to 224x224 and use ImageNet stats for ViT
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# Load the Food-101 training dataset
# Food-101 uses 'split="train"' for training
trainset = torchvision.datasets.Food101(root='./data', split="train",
                                        download=True, transform=transform)

# Load the Food-101 test (validation) dataset
# Food-101 uses 'split="test"' for testing
testset = torchvision.datasets.Food101(root='./data', split="test",
                                       download=True, transform=transform)

print("Food-101 dataset imported successfully.")
print(f"Training set size: {len(trainset)}")
print(f"Test set size: {len(testset)}")
# Out:
# 100%|██████████| 5.00G/5.00G [00:22<00:00, 223MB/s]
# Food-101 dataset imported successfully.
# Training set size: 75750
# Test set size: 25250

# %% [markdown]
# #### Resizing the data for ViT model

# %%
import torchvision.transforms as transforms

# Define transforms for training and validation/testing
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Upsample to ViT resolution
    transforms.RandomHorizontalFlip(), # Example data augmentation
    transforms.RandomCrop(224, padding=4), # Example data augmentation
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)), # Upsample to ViT resolution
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Apply the transforms to the datasets
trainset.transform = train_transform
testset.transform = test_transform

print("Data preparation complete. Transforms applied to datasets.")
# Out:
# Data preparation complete. Transforms applied to datasets.

# %% [markdown]
# #### Loading the VIT and freezing the parameters

# %%
from transformers import ViTForImageClassification

# Load a pre-trained ViT-Huge model
model = ViTForImageClassification.from_pretrained(
    'google/vit-huge-patch14-224-in21k',  # Model name for ViT-Huge
    num_labels=101,                       # Updated for 101 classes in Food-101
    ignore_mismatched_sizes=True          # Allows replacing the classifier head
)

print("Pre-trained ViT-Huge model loaded.")
# Out:
# 2025-11-30 18:41:27.998628: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764528088.134481      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764528088.176033      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.53G [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-huge-patch14-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Pre-trained ViT-Huge model loaded.

# %%
# %pip install peft transformers datasets

# %% [markdown]
# # Here we decide if we want to train full model or some

# %%
# Print the number of trainable parameters
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Number of trainable parameters: {trainable_params}")
# Out:
# Number of trainable parameters: 630894181

# %%
# model

# %% [markdown]
# ## Step 1: Create the DataLoaders

# %%
from torch.utils.data import DataLoader

# Create DataLoaders
train_loader = DataLoader(trainset, batch_size=16, shuffle=True)
test_loader = DataLoader(testset, batch_size=16, shuffle=False)

print("DataLoaders created.")
# Out:
# DataLoaders created.

# %% [markdown]
# ## Step 2: Enable Gradient Checkpointing

# %%
# Enable gradient checkpointing
model.gradient_checkpointing_enable()
print("Gradient checkpointing enabled.")
# Out:
# Gradient checkpointing enabled.

# %% [markdown]
# ## Step 3: Initialize DeepSpeed

# %%
# %pip install mpi4py
# Out:
# Collecting mpi4py
#   Downloading mpi4py-4.1.1-cp311-cp311-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (16 kB)
# Downloading mpi4py-4.1.1-cp311-cp311-manylinux1_x86_64.manylinux_2_5_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.5 MB/s eta 0:00:0000:010:01
# Installing collected packages: mpi4py
# Successfully installed mpi4py-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install deepspeed
# Out:
# Collecting deepspeed
#   Downloading deepspeed-0.18.2.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.4 MB/s eta 0:00:0000:010:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from deepspeed) (0.8.1)
# Collecting hjson (from deepspeed)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from deepspeed) (1.1.2)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from deepspeed) (1.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from deepspeed) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from deepspeed) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from deepspeed) (7.1.3)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from deepspeed) (9.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from deepspeed) (2.12.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from deepspeed) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from deepspeed) (4.67.1)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.11/dist-packages (from deepspeed) (12.575.51)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0.0->deepspeed) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0.0->deepspeed) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0.0->deepspeed) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0.0->deepspeed) (0.4.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->deepspeed) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->deepspeed) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->deepspeed) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->deepspeed) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->deepspeed) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->deepspeed) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (3.20.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->deepspeed)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->deepspeed)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->deepspeed)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->deepspeed)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->deepspeed)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->deepspeed)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->deepspeed)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->deepspeed)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->deepspeed)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->deepspeed)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->deepspeed) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->deepspeed) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->deepspeed) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->deepspeed) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->deepspeed) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->deepspeed) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->deepspeed) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->deepspeed) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->deepspeed) (2024.2.0)
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 24.3 MB/s eta 0:00:0000:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.7 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.5 MB/s eta 0:00:0000:0100:01m
# Building wheels for collected packages: deepspeed
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.18.2-py3-none-any.whl size=1763310 sha256=c7d90fbfeac226633a88638bc3f0a16f0184c1df099f76f700a5aefb0146b1e1
#   Stored in directory: /root/.cache/pip/wheels/80/2b/fe/f2625302f25976b9828a27d3d2567bdc1d587a1ff0ab42c8a9
# Successfully built deepspeed
# Installing collected packages: hjson, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, deepspeed
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed deepspeed-0.18.2 hjson-3.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Note: you may need to restart the kernel to use updated packages.

# %%
# !apt-get install -y libaio-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libaio-dev
# 0 upgraded, 1 newly installed, 0 to remove and 165 not upgraded.
# Need to get 21.2 kB of archives.
# After this operation, 71.7 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaio-dev amd64 0.3.112-13build1 [21.2 kB]
# Fetched 21.2 kB in 0s (238 kB/s)
# Selecting previously unselected package libaio-dev:amd64.
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../libaio-dev_0.3.112-13build1_amd64.deb ...
# Unpacking libaio-dev:amd64 (0.3.112-13build1) ...
# Setting up libaio-dev:amd64 (0.3.112-13build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ## Script for Standard Full Fine-Tune Using DDP, running on 2 T4 gpus batch size = 16 per gpu

# %%
# %%writefile train_standard_ddp_vit_huge_bs16.py
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from transformers import ViTForImageClassification, ViTImageProcessor
import warnings
import wandb
import os
import time
import torch.distributed as dist
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data.distributed import DistributedSampler
from torch.cuda.amp import GradScaler, autocast
import torch.profiler 

# --- 1. Setup & Helper Functions ---
warnings.filterwarnings("ignore")
print("--- Initializing Standard DDP (PRO RUN) ---")

rank = int(os.environ['RANK'])
local_rank = int(os.environ['LOCAL_RANK'])
world_size = int(os.environ['WORLD_SIZE'])

dist.init_process_group(backend='nccl')
torch.cuda.set_device(local_rank)
device = torch.device(f"cuda:{local_rank}")

def inspect_model_sharding(model, name_tag):
    """Checks if parameters are sharded (Expected: NO for DDP)"""
    if rank == 0:
        print(f"\n[Rank {rank}] --- INSPECTING SHARDING ({name_tag}) ---")
        # Unwrap DDP to get to the actual model parameters
        actual_model = model.module if hasattr(model, "module") else model
        
        count = 0
        for name, param in actual_model.named_parameters():
            print(f"Param: {name}")
            # In DDP, Physical Shape should equal Logical Shape (Full Layer)
            print(f"  Physical Shape: {param.shape} (Elements: {param.numel():,})")
            print(f"  Status:         REPLICATED (Full Copy)")
            print("-" * 40)
            count += 1
            if count >= 2: break
        print("----------------------------------\n")

# --- 2. Data & Model ---
if rank == 0: print("Setting up Data & Model...")
processor = ViTImageProcessor.from_pretrained('google/vit-huge-patch14-224-in21k')
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std)
])

if rank == 0:
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=True, transform=train_transform)
dist.barrier()
if rank != 0:
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=False, transform=train_transform)

train_sampler = DistributedSampler(trainset, num_replicas=world_size, rank=rank, shuffle=True)
train_loader = DataLoader(trainset, batch_size=16, sampler=train_sampler, num_workers=2, pin_memory=True)

model = ViTForImageClassification.from_pretrained('google/vit-huge-patch14-224-in21k', num_labels=101, ignore_mismatched_sizes=True)
model.gradient_checkpointing_enable()
model.to(device)
model = DDP(model, device_ids=[local_rank], output_device=local_rank)

optimizer = optim.AdamW(model.parameters(), lr=5e-5)
scaler = GradScaler(enabled=True)

# --- 3. Logging & Inspection ---
if rank == 0:
    wandb.init(
        project="Distributed ViT training systems-Latest_run",
        name="Standard-DDP-ViT-Huge-Food101-2xT4-Batch-size-16-per-gpu",
        config={"model": "vit-huge", "mode": "DDP"}
    )

# PRO CHECK: This output will prove that DDP duplicates the full model on every GPU
inspect_model_sharding(model, "Standard DDP")

# --- 4. Training Loop with Labels ---
print(f"[Rank {rank}] Starting training...")

for i, batch in enumerate(train_loader):
    # Stop early to save time (we just need traces and logs)
    if i >= 6: break
    
    # LABEL 0: Top Level Step
    with torch.profiler.record_function(f"## Training Step {i} ##"):
        inputs, labels = batch
        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad(set_to_none=True)

        # LABEL 1: Forward
        with torch.profiler.record_function("## Forward Pass ##"):
            with autocast(enabled=True):
                outputs = model(inputs, labels=labels)
                loss = outputs.loss

        # LABEL 2: Backward
        with torch.profiler.record_function("## Backward Pass ##"):
            # This is where it usually crashes (OOM)
            scaler.scale(loss).backward()

        # LABEL 3: Optimizer
        with torch.profiler.record_function("## Optimizer Step ##"):
            scaler.step(optimizer)
            scaler.update()

        # --- PRO LOGGING ---
        if rank == 0:
            mem = torch.cuda.memory_allocated() / 1e9
            max_mem = torch.cuda.max_memory_allocated() / 1e9
            wandb.log({
                "loss": loss.item(),
                "System/Memory_Allocated_GB": mem,
                "System/Max_Memory_GB": max_mem
            })
            print(f"Step {i}: Loss={loss.item():.4f} | Mem={mem:.2f}GB")

dist.destroy_process_group()
# Out:
# Writing train_standard_ddp_vit_huge_bs16.py

# %%
# 1. Install/Login
# !pip install -q transformers datasets peft deepspeed wandb scikit-learn seaborn tensorboard
# !wandb login

# 2. Launch the DDP script
# !torchrun --nproc_per_node=2 train_standard_ddp.py
# !torchrun --nproc_per_node=2 --master_port 29501 train_standard_ddp_vit_huge_bs16.py
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 36.6 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Currently logged in as: siddpath (siddpath-university-of-maryland) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# W1124 00:55:01.430000 328 torch/distributed/run.py:792]
# W1124 00:55:01.430000 328 torch/distributed/run.py:792] *****************************************
# W1124 00:55:01.430000 328 torch/distributed/run.py:792] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W1124 00:55:01.430000 328 torch/distributed/run.py:792] *****************************************
# 2025-11-24 00:55:06.747747: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-24 00:55:06.747800: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763945706.769617     330 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763945706.769631     331 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763945706.776907     330 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1763945706.777083     331 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeErrorAttributeError: : 'MessageFactory' object has no attribute 'GetPrototype''MessageFactory' object has no attribute 'GetPrototype'
#
# AttributeError: AttributeError'MessageFactory' object has no attribute 'GetPrototype': 'MessageFactory' object has no attribute 'GetPrototype'
#
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# --- Initializing Standard DDP (PRO RUN) ---
# Setting up Data & Model...
# --- Initializing Standard DDP (PRO RUN) ---
# preprocessor_config.json: 100%|█████████████████| 160/160 [00:00<00:00, 923kB/s]
# [rank1]:[W1124 00:55:14.656962491 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 1]  using GPU 1 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# [rank0]:[W1124 00:55:15.954040573 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-huge-patch14-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-huge-patch14-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Rank 1] Starting training...
# wandb: Currently logged in as: siddpath (siddpath-university-of-maryland) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20251124_005518-8hohk4al
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Standard-DDP-ViT-Huge-Food101-2xT4-Batch-size-16-per-gpu
# wandb: ⭐️ View project at https://wandb.ai/siddpath-university-of-maryland/Distributed%20ViT%20training%20systems-Latest_run
# wandb: 🚀 View run at https://wandb.ai/siddpath-university-of-maryland/Distributed%20ViT%20training%20systems-Latest_run/runs/8hohk4al
#
# [Rank 0] --- INSPECTING SHARDING (Standard DDP) ---
# Param: vit.embeddings.cls_token
#   Physical Shape: torch.Size([1, 1, 1280]) (Elements: 1,280)
#   Status:         REPLICATED (Full Copy)
# ----------------------------------------
# Param: vit.embeddings.position_embeddings
#   Physical Shape: torch.Size([1, 257, 1280]) (Elements: 328,960)
#   Status:         REPLICATED (Full Copy)
# ----------------------------------------
# ----------------------------------
#
# [Rank 0] Starting training...
# Traceback (most recent call last):
# [rank1]: Traceback (most recent call last):
# [rank1]:   File "/kaggle/working/train_standard_ddp_vit_huge_bs16.py", line 113, in <module>
# [rank1]:     scaler.step(optimizer)
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py", line 457, in step
# [rank1]:     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
# [rank1]:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py", line 352, in _maybe_opt_step
# [rank1]:     retval = optimizer.step(*args, **kwargs)
# [rank1]:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 493, in wrapper
# [rank1]:     out = func(*args, **kwargs)
# [rank1]:           ^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 91, in _use_grad
# [rank1]:     ret = func(self, *args, **kwargs)
# [rank1]:           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 243, in step
# [rank1]:     adamw(
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 154, in maybe_fallback
# [rank1]:     return func(*args, **kwargs)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 875, in adamw
# [rank1]:     func(
# [rank1]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 699, in _multi_tensor_adamw
# [rank1]:     exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
# [rank1]:                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]: torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 26.00 MiB. GPU 1 has a total capacity of 14.74 GiB of which 6.12 MiB is free. Process 11089 has 14.73 GiB memory in use. Of the allocated memory 12.80 GiB is allocated by PyTorch, and 1.71 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#   File "/kaggle/working/train_standard_ddp_vit_huge_bs16.py", line 113, in <module>
#     scaler.step(optimizer)
#   File "/usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py", line 457, in step
#     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py", line 352, in _maybe_opt_step
#     retval = optimizer.step(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 493, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 91, in _use_grad
#     ret = func(self, *args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 243, in step
#     adamw(
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 154, in maybe_fallback
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 875, in adamw
#     func(
#   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 699, in _multi_tensor_adamw
#     exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 26.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 8.12 MiB is free. Process 6892 has 102.00 MiB memory in use. Process 11088 has 14.63 GiB memory in use. Of the allocated memory 12.65 GiB is allocated by PyTorch, and 1.76 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/kaggle/working/train_standard_ddp_vit_huge_bs16.py", line 113, in <module>
# [rank0]:     scaler.step(optimizer)
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py", line 457, in step
# [rank0]:     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
# [rank0]:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py", line 352, in _maybe_opt_step
# [rank0]:     retval = optimizer.step(*args, **kwargs)
# [rank0]:              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 493, in wrapper
# [rank0]:     out = func(*args, **kwargs)
# [rank0]:           ^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 91, in _use_grad
# [rank0]:     ret = func(self, *args, **kwargs)
# [rank0]:           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 243, in step
# [rank0]:     adamw(
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py", line 154, in maybe_fallback
# [rank0]:     return func(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 875, in adamw
# [rank0]:     func(
# [rank0]:   File "/usr/local/lib/python3.11/dist-packages/torch/optim/adamw.py", line 699, in _multi_tensor_adamw
# [rank0]:     exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
# [rank0]:                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]: torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 26.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 8.12 MiB is free. Process 6892 has 102.00 MiB memory in use. Process 11088 has 14.63 GiB memory in use. Of the allocated memory 12.65 GiB is allocated by PyTorch, and 1.76 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# wandb:
# wandb: 🚀 View run Standard-DDP-ViT-Huge-Food101-2xT4-Batch-size-16-per-gpu at: https://wandb.ai/siddpath-university-of-maryland/Distributed%20ViT%20training%20systems-Latest_run/runs/8hohk4al
# wandb: Find logs at: wandb/run-20251124_005518-8hohk4al/logs
# [rank0]:[W1124 00:55:24.169937531 ProcessGroupNCCL.cpp:1496] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# W1124 00:55:25.206000 328 torch/distributed/elastic/multiprocessing/api.py:897] Sending process 330 closing signal SIGTERM
# E1124 00:55:25.521000 328 torch/distributed/elastic/multiprocessing/api.py:869] failed (exitcode: 1) local_rank: 1 (pid: 331) of binary: /usr/bin/python3
# Traceback (most recent call last):
#   File "/usr/local/bin/torchrun", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributed/elastic/multiprocessing/errors/__init__.py", line 355, in wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributed/run.py", line 918, in main
#     run(args)
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributed/run.py", line 909, in run
#     elastic_launch(
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributed/launcher/api.py", line 138, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributed/launcher/api.py", line 269, in launch_agent
#     raise ChildFailedError(
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# train_standard_ddp_vit_huge_bs16.py FAILED
# ------------------------------------------------------------
# Failures:
#   <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2025-11-24_00:55:25
#   host      : 287223b48a86
#   rank      : 1 (local_rank: 1)
#   exitcode  : 1 (pid: 331)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================

# %% [markdown]
# ## Script for DeepSpeed Full Fine-Tune, running on 2 T4 gpus stage 2

# %%
# %%writefile deepspeed_config_stage2_vit_huge_bs16.json
# {
#     "fp16": {
#         "enabled": true,
#         "loss_scale": 0,
#         "loss_scale_window": 1000
#     },
#     "optimizer": {
#         "type": "AdamW",
#         "params": {
#             "lr": 5e-5,
#             "betas": [0.9, 0.999],
#             "eps": 1e-8,
#             "weight_decay": 3e-7
#         }
#     },
#     "zero_optimization": {
#         "stage": 2,
#         "allgather_partitions": true,
#         "allgather_bucket_size": 5e8,
#         "reduce_scatter": true,
#         "reduce_bucket_size": 5e8,
#         "overlap_comm": true,
#         "contiguous_gradients": true
#     },
#     "train_batch_size": 32,
#     "train_micro_batch_size_per_gpu": 16,
#     "gradient_accumulation_steps": 1,
#     "gradient_clipping": 1.0,
#     "steps_per_print": 50,
#     "wall_clock_breakdown": true,
#     "flops_profiler": {
#         "enabled": true,
#         "profile_step": 5,
#         "module_depth": -1,
#         "top_modules": 1,
#         "detailed": true,
#         "output_file": null
#     }
# }
# Out:
# Writing deepspeed_config_stage2_vit_huge_bs16.json

# %%
# %%writefile train_deepspeed_stage2_vit_huge_bs16.py
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from transformers import ViTForImageClassification, ViTImageProcessor
import deepspeed
import warnings
import wandb
import os
import time
import torch.distributed as dist
from torch.utils.data.distributed import DistributedSampler
from sklearn.metrics import confusion_matrix
import torch.profiler # <--- PRO ADDITION

# Suppress warnings
warnings.filterwarnings("ignore")
print("--- Initializing DEEPSPEED ZeRO Stage 2 (PRO RUN) ---")

# --- 1. Setup ---
local_rank = int(os.environ['LOCAL_RANK'])
rank = int(os.environ['RANK'])
world_size = int(os.environ['WORLD_SIZE'])
torch.cuda.set_device(local_rank)
print(f"[Rank {rank}] Initializing process...")

# --- W&B Setup ---
if rank == 0:
    WANDB_PROJECT = "Distributed ViT training systems-Latest_run"
    WANDB_RUN_NAME = "DeepSpeed-Stage2-ViT-Huge-Food101-2xT4-MBS16-GAS1-Batch-size-16-per-gpu"

# --- HELPER: PROVE NO SHARDING ---
def inspect_model_sharding(model):
    """Stage 2 should show NO parameter sharding (Physical == Logical)"""
    if rank == 0:
        print(f"\n[Rank {rank}] --- INSPECTING SHARDING (Stage 2) ---")
        count = 0
        for name, param in model.named_parameters():
            # In Stage 2, parameters are NOT partitioned by default
            print(f"Param: {name}")
            print(f"  Physical Shape: {param.shape}")
            print(f"  Status:         Full Layer Present (High Memory)")
            print("-" * 40)
            count += 1
            if count >= 2: break
        print("----------------------------------\n")

# --- 2. Model Setup ---
if rank == 0:
    print("Loading pre-trained ViT-Huge model...")
model = ViTForImageClassification.from_pretrained('google/vit-huge-patch14-224-in21k', num_labels=101, ignore_mismatched_sizes=True)
model.gradient_checkpointing_enable()

# --- 3. DeepSpeed Init ---
if rank == 0: print("Initializing DeepSpeed...")
model_engine, optimizer, _, _ = deepspeed.initialize(
    model=model, model_parameters=model.parameters(), 
    config_params='deepspeed_config_stage2_vit_huge_bs16.json'
)

# --- 4. Data Prep ---
if rank == 0: print("Setting up data...")
processor = ViTImageProcessor.from_pretrained('google/vit-huge-patch14-224-in21k')
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std)
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std)
])

if rank == 0:
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=True, transform=train_transform)
    testset = torchvision.datasets.Food101(root='./data', split="test", download=True, transform=test_transform)
dist.barrier() 
if rank != 0:
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=False, transform=train_transform)
    testset = torchvision.datasets.Food101(root='./data', split="test", download=False, transform=test_transform)

MICRO_BATCH_SIZE = 16
train_sampler = DistributedSampler(trainset, num_replicas=world_size, rank=rank, shuffle=True)
test_sampler = DistributedSampler(testset, num_replicas=world_size, rank=rank, shuffle=False)
train_loader = DataLoader(trainset, batch_size=MICRO_BATCH_SIZE, sampler=train_sampler, num_workers=2, pin_memory=True)
test_loader = DataLoader(testset, batch_size=MICRO_BATCH_SIZE, sampler=test_sampler, num_workers=2, pin_memory=True)

# --- 6. WANDB INIT ---
if rank == 0:
    wandb.init(
        project=WANDB_PROJECT, name=WANDB_RUN_NAME,
        config={"model": "vit-huge", "optimization": "Stage 2"}
    )

# Run Check
inspect_model_sharding(model_engine.module)

# --- 7. Training Loop ---
device = model_engine.device
num_epochs = 1
start_time = time.time()

for epoch in range(num_epochs):
    model_engine.train()
    train_sampler.set_epoch(epoch)
    total_loss_rank = 0.0
    
    for i, batch in enumerate(train_loader):
        
        # PRO LABEL: Top Level
        with torch.profiler.record_function(f"## Training Step {i} ##"):
            inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device)

            # PRO LABEL: Forward (Clean)
            with torch.profiler.record_function("## Forward Pass ##"):
                outputs = model_engine(inputs, labels=labels)
                loss = outputs.loss

            # PRO LABEL: Backward (Blocking)
            with torch.profiler.record_function("## Backward Pass ##"):
                model_engine.backward(loss)

            # PRO LABEL: Optimizer
            with torch.profiler.record_function("## Optimizer Step ##"):
                model_engine.step()

            total_loss_rank += loss.item()
            
            # --- PRO LOGGING ---
            if rank == 0:
                mem = torch.cuda.memory_allocated() / 1e9
                if hasattr(model_engine, 'tput_timer'):
                    tput = model_engine.tput_timer.avg_samples_per_sec
                else: tput = 0
                
                wandb.log({"step_loss": loss.item(), "System/Memory_Allocated_GB": mem, "Performance/Throughput": tput})
                if i % 100 == 0: print(f"  Step {i}: Loss={loss.item():.4f} | Mem={mem:.2f}GB")

    # Sync Loss
    total_loss_all_ranks = torch.tensor(total_loss_rank, dtype=torch.float, device=device)
    dist.all_reduce(total_loss_all_ranks, op=dist.ReduceOp.SUM)
    
    if rank == 0:
        avg_train_loss = total_loss_all_ranks.item() / (len(train_loader) * world_size)
        duration = time.time() - start_time
        wandb.log({"epoch": 1, "avg_train_loss": avg_train_loss, "epoch_duration_sec": duration})

if rank == 0:
    total_time = time.time() - start_time
    wandb.log({"total_training_time_sec": total_time})

# --- 8. Evaluation ---
if rank == 0: print("--- Starting evaluation ---")
model_engine.eval()
rank_preds = []
rank_labels = []

with torch.no_grad():
    for batch in test_loader:
        inputs, labels = batch
        inputs = inputs.to(device)
        labels_cpu = labels.cpu() 
        outputs = model_engine(inputs)
        _, predicted = torch.max(outputs.logits.data, 1)
        rank_preds.extend(predicted.cpu().numpy())
        rank_labels.extend(labels_cpu.numpy())

all_preds = [None] * world_size
all_labels = [None] * world_size
dist.all_gather_object(all_preds, rank_preds)
dist.all_gather_object(all_labels, rank_labels)

if rank == 0:
    print("Computing metrics...")
    flat_preds = [item for sublist in all_preds for item in sublist]
    flat_labels = [item for sublist in all_labels for item in sublist]
    
    correct = (torch.tensor(flat_preds) == torch.tensor(flat_labels)).sum().item()
    accuracy = 100 * correct / len(flat_preds)
    print(f"**Final Test Accuracy: {accuracy:.2f}%**")

    wandb.log({"final_test_accuracy": accuracy})
    wandb_cm = wandb.plot.confusion_matrix(preds=flat_preds, y_true=flat_labels, class_names=trainset.classes)
    wandb.log({"confusion_matrix": wandb_cm})
    wandb.finish()

dist.destroy_process_group()
print(f"--- [Rank {rank}] Run complete ---")
# Out:
# Writing train_deepspeed_stage2_vit_huge_bs16.py

# %%
# !deepspeed --num_gpus=2 train_deepspeed_stage2_vit_huge_bs16.py
# Out:
# 2025-11-24 00:55:34.322063: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763945734.344443     407 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763945734.352258     407 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [2025-11-24 00:55:39,427] [WARNING] [runner.py:232:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2025-11-24 00:55:39,427] [INFO] [runner.py:630:main] cmd = /usr/bin/python3 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMV19 --master_addr=127.0.0.1 --master_port=29500 --enable_each_rank_log=None --log_level=info train_deepspeed_stage2_vit_huge_bs16.py
# 2025-11-24 00:55:46.565485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763945746.588324     459 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763945746.595129     459 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [2025-11-24 00:55:51,659] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_DEV_PACKAGE=libnccl-dev=2.22.3-1+cuda12.5
# [2025-11-24 00:55:51,660] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_DEV_PACKAGE_VERSION=2.22.3-1
# [2025-11-24 00:55:51,660] [INFO] [launch.py:155:main] 0 NCCL_VERSION=2.22.3-1
# [2025-11-24 00:55:51,660] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_DEV_PACKAGE_NAME=libnccl-dev
# [2025-11-24 00:55:51,660] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_PACKAGE=libnccl2=2.22.3-1+cuda12.5
# [2025-11-24 00:55:51,660] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_PACKAGE_NAME=libnccl2
# [2025-11-24 00:55:51,660] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_PACKAGE_VERSION=2.22.3-1
# [2025-11-24 00:55:51,660] [INFO] [launch.py:162:main] WORLD INFO DICT: {'localhost': [0, 1]}
# [2025-11-24 00:55:51,660] [INFO] [launch.py:168:main] nnodes=1, num_local_procs=2, node_rank=0
# [2025-11-24 00:55:51,660] [INFO] [launch.py:179:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1]})
# [2025-11-24 00:55:51,660] [INFO] [launch.py:180:main] dist_world_size=2
# [2025-11-24 00:55:51,660] [INFO] [launch.py:184:main] Setting CUDA_VISIBLE_DEVICES=0,1
# [2025-11-24 00:55:51,661] [INFO] [launch.py:272:main] process 511 spawned with command: ['/usr/bin/python3', '-u', 'train_deepspeed_stage2_vit_huge_bs16.py', '--local_rank=0']
# [2025-11-24 00:55:51,662] [INFO] [launch.py:272:main] process 512 spawned with command: ['/usr/bin/python3', '-u', 'train_deepspeed_stage2_vit_huge_bs16.py', '--local_rank=1']
# 2025-11-24 00:55:56.643032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763945756.665593     512 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-24 00:55:56.666789: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1763945756.672880     512 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763945756.689748     511 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763945756.707649     511 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# --- Initializing DEEPSPEED ZeRO Stage 2 (PRO RUN) ---
# [Rank 0] Initializing process...
# Loading pre-trained ViT-Huge model...
# --- Initializing DEEPSPEED ZeRO Stage 2 (PRO RUN) ---
# [Rank 1] Initializing process...
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-huge-patch14-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Initializing DeepSpeed...
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-huge-patch14-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [rank1]:[W1124 00:56:48.532700967 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 1]  using GPU 1 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# Setting up data...
# [rank0]:[W1124 00:56:50.789283865 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# wandb: Currently logged in as: siddpath (siddpath-university-of-maryland) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20251124_005650-yknwyj7v
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run DeepSpeed-Stage2-ViT-Huge-Food101-2xT4-MBS16-GAS1-Batch-size-16-per-gpu
# wandb: ⭐️ View project at https://wandb.ai/siddpath-university-of-maryland/Distributed%20ViT%20training%20systems-Latest_run
# wandb: 🚀 View run at https://wandb.ai/siddpath-university-of-maryland/Distributed%20ViT%20training%20systems-Latest_run/runs/yknwyj7v
#
# [Rank 0] --- INSPECTING SHARDING (Stage 2) ---
# Param: vit.embeddings.cls_token
#   Physical Shape: torch.Size([1, 1, 1280])
#   Status:         Full Layer Present (High Memory)
# ----------------------------------------
# Param: vit.embeddings.position_embeddings
#   Physical Shape: torch.Size([1, 257, 1280])
#   Status:         Full Layer Present (High Memory)
# ----------------------------------------
# ----------------------------------
#
# [Rank 0] time (ms) | fwd_microstep: 836.05 | bwd_microstep: 1206.17 | bwd_inner_microstep: 1114.13 | bwd_allreduce_microstep: 71.50 | step_microstep: 181.63
# [Rank 0] time (ms) | fwd: 835.91 | bwd: 1206.14 | bwd_inner: 1114.09 | bwd_allreduce: 71.54 | step: 181.63
#   Step 0: Loss=4.5820 | Mem=2.55GB
# [Rank 0] time (ms) | fwd_microstep: 308.66 | bwd_microstep: 1193.90 | bwd_inner_microstep: 1123.23 | bwd_allreduce_microstep: 70.61 | step_microstep: 53.08
# [Rank 0] time (ms) | fwd: 308.64 | bwd: 1193.91 | bwd_inner: 1123.23 | bwd_allreduce: 70.63 | step: 53.08
# [Rank 0] time (ms) | optimizer_allgather: 199.03 | optimizer_gradients: 60.11 | optimizer_step: 64.28
# [Rank 0] time (ms) | fwd_microstep: 313.16 | bwd_microstep: 1326.34 | bwd_inner_microstep: 1255.34 | bwd_allreduce_microstep: 70.90 | step_microstep: 732.86
# [Rank 0] time (ms) | fwd: 313.14 | bwd: 1326.36 | bwd_inner: 1255.34 | bwd_allreduce: 70.93 | step: 732.85
# [Rank 0] time (ms) | optimizer_allgather: 202.08 | optimizer_gradients: 26.26 | optimizer_step: 52.76
# [Rank 0] time (ms) | fwd_microstep: 308.84 | bwd_microstep: 1344.10 | bwd_inner_microstep: 1273.77 | bwd_allreduce_microstep: 70.28 | step_microstep: 363.34
# [Rank 0] time (ms) | fwd: 308.83 | bwd: 1344.11 | bwd_inner: 1273.77 | bwd_allreduce: 70.30 | step: 363.34
# [Rank 0] time (ms) | optimizer_allgather: 201.83 | optimizer_gradients: 26.21 | optimizer_step: 52.70
# [Rank 0] time (ms) | fwd_microstep: 315.98 | bwd_microstep: 1353.00 | bwd_inner_microstep: 1282.72 | bwd_allreduce_microstep: 70.22 | step_microstep: 362.80
# [Rank 0] time (ms) | fwd: 315.97 | bwd: 1353.01 | bwd_inner: 1282.72 | bwd_allreduce: 70.24 | step: 362.81
# [Rank 0] time (ms) | optimizer_allgather: 202.33 | optimizer_gradients: 26.26 | optimizer_step: 52.62
#
# -------------------------- DeepSpeed Flops Profiler --------------------------
# Profile Summary at step 6:
# Notations:
# data parallel size (dp_size), model parallel size(mp_size),
# number of parameters (params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (flops), floating-point operations per second (FLOPS),
# fwd latency (forward propagation latency), bwd latency (backward propagation latency),
# step (weights update latency), iter latency (sum of fwd, bwd and step latency)
#
# world size:                                                             2
# data parallel size:                                                     2
# model parallel size:                                                    1
# batch size per GPU:                                                     16
# params per GPU:                                                         630.89 M
# params of model = params per GPU * mp_size:                             630.89 M
# fwd MACs per GPU:                                                       2.68 TMACs
# fwd flops per GPU:                                                      5.36 T
# fwd flops of model = fwd flops per GPU * mp_size:                       5.36 T
# fwd latency:                                                            321.88 ms
# fwd FLOPS per GPU = fwd flops per GPU / fwd latency:                    16.64 TFLOPS
# bwd latency:                                                            1.33 s
# bwd FLOPS per GPU = 2 * fwd flops per GPU / bwd latency:                8.05 TFLOPS
# fwd+bwd FLOPS per GPU = 3 * fwd flops per GPU / (fwd+bwd latency):      9.72 TFLOPS
# step latency:                                                           363.35 ms
# iter latency:                                                           2.02 s
# FLOPS per GPU = 3 * fwd flops per GPU / iter latency:                   7.97 TFLOPS
# samples/second:                                                         15.87
#
# ----------------------------- Aggregated Profile per GPU -----------------------------
# Top 1 modules in terms of params, MACs or fwd latency at different model depths:
# depth 0:
#     params      - {'ViTForImageClassification': '630.89 M'}
#     MACs        - {'ViTForImageClassification': '2.68 TMACs'}
#     fwd latency - {'ViTForImageClassification': '1.76 Gs'}
# depth 1:
#     params      - {'ViTModel': '630.76 M'}
#     MACs        - {'ViTModel': '2.68 TMACs'}
#     fwd latency - {'ViTModel': '321.38 ms'}
# depth 2:
#     params      - {'ViTEncoder': '629.68 M'}
#     MACs        - {'ViTEncoder': '2.67 TMACs'}
#     fwd latency - {'ViTEncoder': '318.43 ms'}
# depth 3:
#     params      - {'ModuleList': '629.68 M'}
#     MACs        - {'ModuleList': '2.67 TMACs'}
#     fwd latency - {'ModuleList': '310.77 ms'}
# depth 4:
#     params      - {'ViTLayer': '629.68 M'}
#     MACs        - {'ViTLayer': '2.67 TMACs'}
#     fwd latency - {'ViTLayer': '310.77 ms'}
# depth 5:
#     params      - {'ViTAttention': '209.88 M'}
#     MACs        - {'ViTAttention': '948.92 GMACs'}
#     fwd latency - {'ViTAttention': '138.67 ms'}
# depth 6:
#     params      - {'Linear': '419.64 M'}
#     MACs        - {'Linear': '1.72 TMACs'}
#     fwd latency - {'Linear': '126.82 ms'}
#
# ------------------------------ Detailed Profile per GPU ------------------------------
# Each module profile is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, fwd latency, percentage of total fwd latency, fwd FLOPS
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss). They are not counted as submodules, thus not to be printed out. However they make up the difference between a parent's MACs (or latency) and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
# 3. The fwd latency listed in the top module's profile is directly captured at the module forward function in PyTorch, thus it's less than the fwd latency shown above which is captured in DeepSpeed.
#
# ViTForImageClassification(
#   630.89 M = 100% Params, 2.68 TMACs = 100% MACs, 1.76 Gs = 100% latency, 3.04 KFLOPS
#   (vit): ViTModel(
#     630.76 M = 99.98% Params, 2.68 TMACs = 100% MACs, 321.38 ms = 0% latency, 16.66 TFLOPS
#     (embeddings): ViTEmbeddings(
#       1.08 M = 0.17% Params, 3.08 GMACs = 0.12% MACs, 2.45 ms = 0% latency, 2.52 TFLOPS
#       (patch_embeddings): ViTPatchEmbeddings(
#         753.92 K = 0.12% Params, 3.08 GMACs = 0.12% MACs, 1.91 ms = 0% latency, 3.23 TFLOPS
#         (projection): Conv2d(753.92 K = 0.12% Params, 3.08 GMACs = 0.12% MACs, 1.7 ms = 0% latency, 3.62 TFLOPS, 3, 1280, kernel_size=(14, 14), stride=(14, 14))
#       )
#       (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 64.13 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       629.68 M = 99.81% Params, 2.67 TMACs = 99.88% MACs, 318.43 ms = 0% latency, 16.8 TFLOPS
#       (layer): ModuleList(
#         (0): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 8 ms = 0% latency, 20.88 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 3.67 ms = 0% latency, 16.18 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 2.71 ms = 0% latency, 16.93 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 435.59 us = 0% latency, 30.93 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 476.84 us = 0% latency, 28.26 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 449.9 us = 0% latency, 29.95 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 736.71 us = 0% latency, 18.29 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 445.13 us = 0% latency, 30.27 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 96.08 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.9 ms = 0% latency, 28.31 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.4 ms = 0% latency, 38.4 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 383.62 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.61 ms = 0% latency, 33.58 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.35 ms = 0% latency, 40 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 35.29 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 204.32 us = 0% latency, 128.8 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 199.32 us = 0% latency, 132.03 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 7.63 ms = 0% latency, 21.9 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 3.33 ms = 0% latency, 17.8 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 2.64 ms = 0% latency, 17.37 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 424.62 us = 0% latency, 31.73 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 429.87 us = 0% latency, 31.34 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 450.13 us = 0% latency, 29.93 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 567.91 us = 0% latency, 23.73 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 432.01 us = 0% latency, 31.19 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 43.15 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.96 ms = 0% latency, 27.45 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.41 ms = 0% latency, 38.17 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 383.38 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.66 ms = 0% latency, 32.4 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.36 ms = 0% latency, 39.71 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 52.21 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 160.22 us = 0% latency, 164.26 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 155.93 us = 0% latency, 168.78 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 7.67 ms = 0% latency, 21.81 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 3.4 ms = 0% latency, 17.46 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 2.71 ms = 0% latency, 16.94 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 426.53 us = 0% latency, 31.59 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 462.53 us = 0% latency, 29.13 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 456.09 us = 0% latency, 29.54 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 565.29 us = 0% latency, 23.84 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 431.54 us = 0% latency, 31.22 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 42.44 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.95 ms = 0% latency, 27.68 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.41 ms = 0% latency, 38.19 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 379.8 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.63 ms = 0% latency, 33.01 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.36 ms = 0% latency, 39.73 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 38.62 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 176.19 us = 0% latency, 149.36 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 164.27 us = 0% latency, 160.2 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 7.92 ms = 0% latency, 21.1 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 3.21 ms = 0% latency, 18.45 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 2.44 ms = 0% latency, 18.76 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 403.4 us = 0% latency, 33.4 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 426.77 us = 0% latency, 31.57 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 398.64 us = 0% latency, 33.8 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 617.27 us = 0% latency, 21.83 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 447.27 us = 0% latency, 30.13 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 55.31 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.99 ms = 0% latency, 27.02 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.46 ms = 0% latency, 36.99 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 379.8 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.98 ms = 0% latency, 27.24 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.63 ms = 0% latency, 33.02 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 65.8 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 155.69 us = 0% latency, 169.04 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 159.98 us = 0% latency, 164.5 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 8.65 ms = 0% latency, 19.33 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 3.84 ms = 0% latency, 15.46 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 3.04 ms = 0% latency, 15.08 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 488.28 us = 0% latency, 27.6 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 490.67 us = 0% latency, 27.46 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 484.7 us = 0% latency, 27.8 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 655.17 us = 0% latency, 20.57 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 499.49 us = 0% latency, 26.98 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 45.78 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.17 ms = 0% latency, 24.82 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.64 ms = 0% latency, 32.83 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 382.18 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.94 ms = 0% latency, 27.75 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.61 ms = 0% latency, 33.54 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 40.53 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 185.97 us = 0% latency, 141.51 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 153.3 us = 0% latency, 171.67 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 8.92 ms = 0% latency, 18.75 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 3.84 ms = 0% latency, 15.44 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 3.06 ms = 0% latency, 14.98 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 490.9 us = 0% latency, 27.45 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 483.75 us = 0% latency, 27.85 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 490.43 us = 0% latency, 27.47 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 656.84 us = 0% latency, 20.51 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 503.3 us = 0% latency, 26.77 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 46.25 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.25 ms = 0% latency, 23.94 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.63 ms = 0% latency, 33.11 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 398.87 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.16 ms = 0% latency, 24.93 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.89 ms = 0% latency, 28.49 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 36.95 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 159.98 us = 0% latency, 164.5 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 153.54 us = 0% latency, 171.4 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (6): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 10.04 ms = 0% latency, 16.65 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 4.46 ms = 0% latency, 13.31 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 3.56 ms = 0% latency, 12.87 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 583.89 us = 0% latency, 23.08 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 608.44 us = 0% latency, 22.15 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 584.84 us = 0% latency, 23.04 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 740.53 us = 0% latency, 18.2 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 589.61 us = 0% latency, 22.85 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 46.25 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.58 ms = 0% latency, 20.91 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.95 ms = 0% latency, 27.65 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 398.87 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.23 ms = 0% latency, 24.21 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.93 ms = 0% latency, 27.99 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 38.62 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 209.81 us = 0% latency, 125.43 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 170.23 us = 0% latency, 154.59 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (7): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 10.59 ms = 0% latency, 15.79 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 4.55 ms = 0% latency, 13.04 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 3.62 ms = 0% latency, 12.64 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 578.17 us = 0% latency, 23.31 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 613.69 us = 0% latency, 21.96 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 573.4 us = 0% latency, 23.5 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 772.24 us = 0% latency, 17.45 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 591.75 us = 0% latency, 22.77 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 68.43 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.62 ms = 0% latency, 20.59 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 1.97 ms = 0% latency, 27.31 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 414.37 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.61 ms = 0% latency, 20.67 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.16 ms = 0% latency, 24.92 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 83.21 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 173.81 us = 0% latency, 151.41 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 172.85 us = 0% latency, 152.25 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (8): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 11.75 ms = 0% latency, 14.23 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 5.26 ms = 0% latency, 11.28 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 4.12 ms = 0% latency, 11.12 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 674.96 us = 0% latency, 19.96 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 677.59 us = 0% latency, 19.89 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 665.43 us = 0% latency, 20.25 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 920.53 us = 0% latency, 14.64 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 669.48 us = 0% latency, 20.13 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 91.08 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.81 ms = 0% latency, 19.16 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.21 ms = 0% latency, 24.35 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 411.03 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.68 ms = 0% latency, 20.12 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.16 ms = 0% latency, 24.96 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 62.7 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 218.39 us = 0% latency, 120.5 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 206.47 us = 0% latency, 127.46 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (9): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 11.43 ms = 0% latency, 14.62 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 5.38 ms = 0% latency, 11.03 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 4.28 ms = 0% latency, 10.71 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 720.5 us = 0% latency, 18.7 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 673.29 us = 0% latency, 20.01 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 696.66 us = 0% latency, 19.34 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 872.14 us = 0% latency, 15.45 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 653.74 us = 0% latency, 20.61 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 64.85 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.67 ms = 0% latency, 20.21 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.17 ms = 0% latency, 24.81 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 369.79 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.4 ms = 0% latency, 22.42 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.09 ms = 0% latency, 25.82 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 63.9 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 222.68 us = 0% latency, 118.18 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 193.36 us = 0% latency, 136.1 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (10): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 10.14 ms = 0% latency, 16.48 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 4.57 ms = 0% latency, 12.99 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 3.73 ms = 0% latency, 12.28 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 615.36 us = 0% latency, 21.9 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 635.62 us = 0% latency, 21.2 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 614.17 us = 0% latency, 21.94 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 730.99 us = 0% latency, 18.43 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 616.31 us = 0% latency, 21.86 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 33.38 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.59 ms = 0% latency, 20.85 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.12 ms = 0% latency, 25.41 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 368.83 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.32 ms = 0% latency, 23.21 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.08 ms = 0% latency, 25.86 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 33.14 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 188.35 us = 0% latency, 139.72 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 166.42 us = 0% latency, 158.14 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (11): ViTLayer(
#           19.68 M = 3.12% Params, 83.55 GMACs = 3.12% MACs, 10.06 ms = 0% latency, 16.61 TFLOPS
#           (attention): ViTAttention(
#             6.56 M = 1.04% Params, 29.65 GMACs = 1.11% MACs, 4.49 ms = 0% latency, 13.21 TFLOPS
#             (attention): ViTSelfAttention(
#               4.92 M = 0.78% Params, 22.92 GMACs = 0.86% MACs, 3.68 ms = 0% latency, 12.46 TFLOPS
#               (query): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 601.53 us = 0% latency, 22.4 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (key): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 639.2 us = 0% latency, 21.08 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (value): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 609.16 us = 0% latency, 22.12 TFLOPS, in_features=1280, out_features=1280, bias=True)
#             )
#             (output): ViTSelfOutput(
#               1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 724.32 us = 0% latency, 18.6 TFLOPS
#               (dense): Linear(1.64 M = 0.26% Params, 6.74 GMACs = 0.25% MACs, 616.79 us = 0% latency, 21.85 TFLOPS, in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 32.9 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.65 ms = 0% latency, 20.36 TFLOPS
#             (dense): Linear(6.56 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.14 ms = 0% latency, 25.24 TFLOPS, in_features=1280, out_features=5120, bias=True)
#             (intermediate_act_fn): GELUActivation(0 = 0% Params, 0 MACs = 0% MACs, 385.28 us = 0% latency, 0 FLOPS)
#           )
#           (output): ViTOutput(
#             6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.31 ms = 0% latency, 23.31 TFLOPS
#             (dense): Linear(6.55 M = 1.04% Params, 26.95 GMACs = 1.01% MACs, 2.08 ms = 0% latency, 25.86 TFLOPS, in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 32.9 us = 0% latency, 0 FLOPS, p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 170.47 us = 0% latency, 154.38 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm(2.56 K = 0% Params, 0 MACs = 0% MACs, 164.03 us = 0% latency, 160.44 GFLOPS, (1280,), eps=1e-12, elementwise_affine=True)
#         )
#         (12): ViTLayer(
# ...
# [Rank 0] time (ms) | optimizer_allgather: 200.91 | optimizer_gradients: 26.17 | optimizer_step: 52.41
# [Rank 0] time (ms) | fwd_microstep: 346.23 | bwd_microstep: 1544.74 | bwd_inner_microstep: 1457.61 | bwd_allreduce_microstep: 87.07 | step_microstep: 361.92
# [Rank 0] time (ms) | fwd: 346.21 | bwd: 1544.75 | bwd_inner: 1457.61 | bwd_allreduce: 87.09 | step: 361.91
# [Rank 0] time (ms) | optimizer_allgather: 201.49 | optimizer_gradients: 26.20 | optimizer_step: 52.40
# [Rank 0] time (ms) | fwd_microstep: 348.36 | bwd_microstep: 1544.91 | bwd_inner_microstep: 1448.81 | bwd_allreduce_microstep: 96.03 | step_microstep: 362.61
# [Rank 0] time (ms) | fwd: 348.34 | bwd: 1544.92 | bwd_inner: 1448.81 | bwd_allreduce: 96.05 | step: 362.62
# [Rank 0] time (ms) | optimizer_allgather: 201.13 | optimizer_gradients: 26.21 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 348.71 | bwd_microstep: 1540.23 | bwd_inner_microstep: 1455.25 | bwd_allreduce_microstep: 84.91 | step_microstep: 362.45
# [Rank 0] time (ms) | fwd: 348.69 | bwd: 1540.24 | bwd_inner: 1455.25 | bwd_allreduce: 84.94 | step: 362.47
# [Rank 0] time (ms) | optimizer_allgather: 201.61 | optimizer_gradients: 26.31 | optimizer_step: 52.43
# [Rank 0] time (ms) | fwd_microstep: 345.04 | bwd_microstep: 1554.46 | bwd_inner_microstep: 1465.64 | bwd_allreduce_microstep: 88.75 | step_microstep: 362.97
# [Rank 0] time (ms) | fwd: 345.02 | bwd: 1554.47 | bwd_inner: 1465.64 | bwd_allreduce: 88.77 | step: 362.96
# [Rank 0] time (ms) | optimizer_allgather: 200.46 | optimizer_gradients: 26.19 | optimizer_step: 52.40
# [Rank 0] time (ms) | fwd_microstep: 343.26 | bwd_microstep: 1540.00 | bwd_inner_microstep: 1453.44 | bwd_allreduce_microstep: 86.50 | step_microstep: 361.68
# [Rank 0] time (ms) | fwd: 343.23 | bwd: 1540.01 | bwd_inner: 1453.44 | bwd_allreduce: 86.52 | step: 361.70
# [Rank 0] time (ms) | optimizer_allgather: 201.22 | optimizer_gradients: 26.21 | optimizer_step: 52.43
# [Rank 0] time (ms) | fwd_microstep: 344.39 | bwd_microstep: 1543.27 | bwd_inner_microstep: 1456.77 | bwd_allreduce_microstep: 86.44 | step_microstep: 362.38
# [Rank 0] time (ms) | fwd: 344.37 | bwd: 1543.28 | bwd_inner: 1456.77 | bwd_allreduce: 86.46 | step: 362.39
# [Rank 0] time (ms) | optimizer_allgather: 201.31 | optimizer_gradients: 26.26 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 345.33 | bwd_microstep: 1533.55 | bwd_inner_microstep: 1451.67 | bwd_allreduce_microstep: 81.82 | step_microstep: 362.78
# [Rank 0] time (ms) | fwd: 345.31 | bwd: 1533.56 | bwd_inner: 1451.67 | bwd_allreduce: 81.84 | step: 362.80
# [Rank 0] time (ms) | optimizer_allgather: 201.67 | optimizer_gradients: 26.27 | optimizer_step: 52.36
# [Rank 0] time (ms) | fwd_microstep: 346.45 | bwd_microstep: 1545.49 | bwd_inner_microstep: 1454.71 | bwd_allreduce_microstep: 90.72 | step_microstep: 362.73
# [Rank 0] time (ms) | fwd: 346.44 | bwd: 1545.50 | bwd_inner: 1454.71 | bwd_allreduce: 90.74 | step: 362.76
# [Rank 0] time (ms) | optimizer_allgather: 200.80 | optimizer_gradients: 26.67 | optimizer_step: 52.46
# [Rank 0] time (ms) | fwd_microstep: 345.86 | bwd_microstep: 1533.81 | bwd_inner_microstep: 1449.97 | bwd_allreduce_microstep: 83.78 | step_microstep: 363.11
# [Rank 0] time (ms) | fwd: 345.84 | bwd: 1533.82 | bwd_inner: 1449.97 | bwd_allreduce: 83.80 | step: 363.13
# [Rank 0] time (ms) | optimizer_allgather: 201.42 | optimizer_gradients: 26.32 | optimizer_step: 52.36
# [Rank 0] time (ms) | fwd_microstep: 343.58 | bwd_microstep: 1546.54 | bwd_inner_microstep: 1453.70 | bwd_allreduce_microstep: 92.78 | step_microstep: 362.72
# [Rank 0] time (ms) | fwd: 343.56 | bwd: 1546.58 | bwd_inner: 1453.70 | bwd_allreduce: 92.80 | step: 362.75
# [Rank 0] time (ms) | optimizer_allgather: 200.80 | optimizer_gradients: 26.17 | optimizer_step: 52.42
# [Rank 0] time (ms) | fwd_microstep: 345.62 | bwd_microstep: 1541.20 | bwd_inner_microstep: 1450.89 | bwd_allreduce_microstep: 90.25 | step_microstep: 361.78
# [Rank 0] time (ms) | fwd: 345.60 | bwd: 1541.21 | bwd_inner: 1450.89 | bwd_allreduce: 90.26 | step: 361.78
# [Rank 0] time (ms) | optimizer_allgather: 201.01 | optimizer_gradients: 26.20 | optimizer_step: 52.41
# [Rank 0] time (ms) | fwd_microstep: 345.75 | bwd_microstep: 1531.89 | bwd_inner_microstep: 1442.86 | bwd_allreduce_microstep: 88.96 | step_microstep: 362.01
# [Rank 0] time (ms) | fwd: 345.73 | bwd: 1531.90 | bwd_inner: 1442.86 | bwd_allreduce: 88.99 | step: 362.04
# [Rank 0] time (ms) | optimizer_allgather: 200.91 | optimizer_gradients: 26.16 | optimizer_step: 52.46
# [Rank 0] time (ms) | fwd_microstep: 343.55 | bwd_microstep: 1532.65 | bwd_inner_microstep: 1444.11 | bwd_allreduce_microstep: 88.47 | step_microstep: 361.98
# [Rank 0] time (ms) | fwd: 343.53 | bwd: 1532.66 | bwd_inner: 1444.11 | bwd_allreduce: 88.49 | step: 362.01
# [Rank 0] time (ms) | optimizer_allgather: 202.05 | optimizer_gradients: 26.23 | optimizer_step: 52.39
# [Rank 0] time (ms) | fwd_microstep: 346.99 | bwd_microstep: 1534.73 | bwd_inner_microstep: 1444.72 | bwd_allreduce_microstep: 89.95 | step_microstep: 363.31
# [Rank 0] time (ms) | fwd: 346.94 | bwd: 1534.74 | bwd_inner: 1444.72 | bwd_allreduce: 89.97 | step: 363.33
# [Rank 0] time (ms) | optimizer_allgather: 200.98 | optimizer_gradients: 26.27 | optimizer_step: 52.38
# [Rank 0] time (ms) | fwd_microstep: 345.11 | bwd_microstep: 1533.08 | bwd_inner_microstep: 1444.70 | bwd_allreduce_microstep: 88.32 | step_microstep: 362.17
# [Rank 0] time (ms) | fwd: 345.09 | bwd: 1533.09 | bwd_inner: 1444.70 | bwd_allreduce: 88.34 | step: 362.18
# [Rank 0] time (ms) | optimizer_allgather: 201.74 | optimizer_gradients: 26.20 | optimizer_step: 52.40
# [Rank 0] time (ms) | fwd_microstep: 346.81 | bwd_microstep: 1533.11 | bwd_inner_microstep: 1440.12 | bwd_allreduce_microstep: 92.93 | step_microstep: 362.67
# [Rank 0] time (ms) | fwd: 346.79 | bwd: 1533.12 | bwd_inner: 1440.12 | bwd_allreduce: 92.95 | step: 362.67
# [Rank 0] time (ms) | optimizer_allgather: 201.14 | optimizer_gradients: 26.17 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 340.97 | bwd_microstep: 1538.70 | bwd_inner_microstep: 1458.05 | bwd_allreduce_microstep: 80.59 | step_microstep: 362.30
# [Rank 0] time (ms) | fwd: 340.95 | bwd: 1538.72 | bwd_inner: 1458.06 | bwd_allreduce: 80.61 | step: 362.30
# [Rank 0] time (ms) | optimizer_allgather: 201.17 | optimizer_gradients: 26.28 | optimizer_step: 52.39
# [Rank 0] time (ms) | fwd_microstep: 346.24 | bwd_microstep: 1532.88 | bwd_inner_microstep: 1448.76 | bwd_allreduce_microstep: 84.05 | step_microstep: 362.21
# [Rank 0] time (ms) | fwd: 346.22 | bwd: 1532.89 | bwd_inner: 1448.76 | bwd_allreduce: 84.07 | step: 362.23
# [Rank 0] time (ms) | optimizer_allgather: 201.10 | optimizer_gradients: 26.18 | optimizer_step: 52.42
# [Rank 0] time (ms) | fwd_microstep: 346.58 | bwd_microstep: 1529.61 | bwd_inner_microstep: 1437.28 | bwd_allreduce_microstep: 92.27 | step_microstep: 362.10
# [Rank 0] time (ms) | fwd: 346.56 | bwd: 1529.62 | bwd_inner: 1437.28 | bwd_allreduce: 92.28 | step: 362.11
# [Rank 0] time (ms) | optimizer_allgather: 201.50 | optimizer_gradients: 26.21 | optimizer_step: 52.40
# [Rank 0] time (ms) | fwd_microstep: 342.06 | bwd_microstep: 1541.17 | bwd_inner_microstep: 1458.28 | bwd_allreduce_microstep: 82.82 | step_microstep: 363.30
# [Rank 0] time (ms) | fwd: 342.02 | bwd: 1541.18 | bwd_inner: 1458.28 | bwd_allreduce: 82.84 | step: 363.31
# [Rank 0] time (ms) | optimizer_allgather: 201.23 | optimizer_gradients: 26.14 | optimizer_step: 52.37
# [Rank 0] time (ms) | fwd_microstep: 341.82 | bwd_microstep: 1536.09 | bwd_inner_microstep: 1448.23 | bwd_allreduce_microstep: 87.81 | step_microstep: 362.15
# [Rank 0] time (ms) | fwd: 341.80 | bwd: 1536.10 | bwd_inner: 1448.23 | bwd_allreduce: 87.82 | step: 362.17
# [Rank 0] time (ms) | optimizer_allgather: 201.18 | optimizer_gradients: 26.21 | optimizer_step: 52.45
# [Rank 0] time (ms) | fwd_microstep: 343.75 | bwd_microstep: 1535.35 | bwd_inner_microstep: 1448.59 | bwd_allreduce_microstep: 86.70 | step_microstep: 362.26
# [Rank 0] time (ms) | fwd: 343.74 | bwd: 1535.36 | bwd_inner: 1448.59 | bwd_allreduce: 86.72 | step: 362.27
# [Rank 0] time (ms) | optimizer_allgather: 200.83 | optimizer_gradients: 26.16 | optimizer_step: 52.38
# [Rank 0] time (ms) | fwd_microstep: 343.00 | bwd_microstep: 1533.79 | bwd_inner_microstep: 1446.10 | bwd_allreduce_microstep: 87.63 | step_microstep: 361.89
# [Rank 0] time (ms) | fwd: 342.98 | bwd: 1533.80 | bwd_inner: 1446.10 | bwd_allreduce: 87.65 | step: 361.89
# [Rank 0] time (ms) | optimizer_allgather: 201.34 | optimizer_gradients: 26.20 | optimizer_step: 52.46
# [Rank 0] time (ms) | fwd_microstep: 345.09 | bwd_microstep: 1535.28 | bwd_inner_microstep: 1447.15 | bwd_allreduce_microstep: 88.07 | step_microstep: 362.56
# [Rank 0] time (ms) | fwd: 345.07 | bwd: 1535.29 | bwd_inner: 1447.15 | bwd_allreduce: 88.09 | step: 362.55
# [Rank 0] time (ms) | optimizer_allgather: 201.14 | optimizer_gradients: 26.19 | optimizer_step: 52.41
# [Rank 0] time (ms) | fwd_microstep: 343.50 | bwd_microstep: 1537.58 | bwd_inner_microstep: 1448.70 | bwd_allreduce_microstep: 88.82 | step_microstep: 362.44
# [Rank 0] time (ms) | fwd: 343.48 | bwd: 1537.59 | bwd_inner: 1448.70 | bwd_allreduce: 88.84 | step: 362.47
# [Rank 0] time (ms) | optimizer_allgather: 201.67 | optimizer_gradients: 26.20 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 341.80 | bwd_microstep: 1538.72 | bwd_inner_microstep: 1452.63 | bwd_allreduce_microstep: 86.03 | step_microstep: 362.81
# [Rank 0] time (ms) | fwd: 341.78 | bwd: 1538.73 | bwd_inner: 1452.63 | bwd_allreduce: 86.05 | step: 362.82
# [Rank 0] time (ms) | optimizer_allgather: 201.10 | optimizer_gradients: 26.17 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 344.30 | bwd_microstep: 1556.08 | bwd_inner_microstep: 1461.94 | bwd_allreduce_microstep: 94.08 | step_microstep: 362.16
# [Rank 0] time (ms) | fwd: 344.28 | bwd: 1556.09 | bwd_inner: 1461.94 | bwd_allreduce: 94.10 | step: 362.17
# [Rank 0] time (ms) | optimizer_allgather: 201.16 | optimizer_gradients: 26.27 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 339.60 | bwd_microstep: 1542.40 | bwd_inner_microstep: 1450.22 | bwd_allreduce_microstep: 92.12 | step_microstep: 362.19
# [Rank 0] time (ms) | fwd: 339.58 | bwd: 1542.42 | bwd_inner: 1450.22 | bwd_allreduce: 92.15 | step: 362.20
# [Rank 0] time (ms) | optimizer_allgather: 200.97 | optimizer_gradients: 26.28 | optimizer_step: 52.39
# [Rank 0] time (ms) | fwd_microstep: 342.85 | bwd_microstep: 1538.95 | bwd_inner_microstep: 1441.26 | bwd_allreduce_microstep: 97.63 | step_microstep: 362.09
# [Rank 0] time (ms) | fwd: 342.83 | bwd: 1538.96 | bwd_inner: 1441.26 | bwd_allreduce: 97.65 | step: 362.10
# [Rank 0] time (ms) | optimizer_allgather: 201.65 | optimizer_gradients: 26.18 | optimizer_step: 52.37
# [Rank 0] time (ms) | fwd_microstep: 343.85 | bwd_microstep: 1527.28 | bwd_inner_microstep: 1442.14 | bwd_allreduce_microstep: 85.08 | step_microstep: 362.72
# [Rank 0] time (ms) | fwd: 343.84 | bwd: 1527.29 | bwd_inner: 1442.14 | bwd_allreduce: 85.10 | step: 362.73
# [Rank 0] time (ms) | optimizer_allgather: 201.23 | optimizer_gradients: 26.24 | optimizer_step: 52.39
# [Rank 0] time (ms) | fwd_microstep: 348.88 | bwd_microstep: 1528.59 | bwd_inner_microstep: 1446.12 | bwd_allreduce_microstep: 82.35 | step_microstep: 362.80
# [Rank 0] time (ms) | fwd: 348.87 | bwd: 1528.60 | bwd_inner: 1446.12 | bwd_allreduce: 82.41 | step: 362.83
# [Rank 0] time (ms) | optimizer_allgather: 201.23 | optimizer_gradients: 26.17 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 342.91 | bwd_microstep: 1536.05 | bwd_inner_microstep: 1453.36 | bwd_allreduce_microstep: 82.63 | step_microstep: 362.34
# [Rank 0] time (ms) | fwd: 342.88 | bwd: 1536.07 | bwd_inner: 1453.36 | bwd_allreduce: 82.65 | step: 362.39
# [Rank 0] time (ms) | optimizer_allgather: 201.56 | optimizer_gradients: 26.19 | optimizer_step: 52.37
# [Rank 0] time (ms) | fwd_microstep: 343.30 | bwd_microstep: 1536.92 | bwd_inner_microstep: 1447.03 | bwd_allreduce_microstep: 89.81 | step_microstep: 362.76
# [Rank 0] time (ms) | fwd: 343.29 | bwd: 1536.93 | bwd_inner: 1447.03 | bwd_allreduce: 89.83 | step: 362.77
# [Rank 0] time (ms) | optimizer_allgather: 201.06 | optimizer_gradients: 26.19 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 345.68 | bwd_microstep: 1534.72 | bwd_inner_microstep: 1446.01 | bwd_allreduce_microstep: 88.65 | step_microstep: 362.42
# [Rank 0] time (ms) | fwd: 345.66 | bwd: 1534.73 | bwd_inner: 1446.01 | bwd_allreduce: 88.67 | step: 362.42
# [Rank 0] time (ms) | optimizer_allgather: 201.05 | optimizer_gradients: 26.16 | optimizer_step: 52.46
# [Rank 0] time (ms) | fwd_microstep: 344.47 | bwd_microstep: 1535.68 | bwd_inner_microstep: 1449.97 | bwd_allreduce_microstep: 85.65 | step_microstep: 362.23
# [Rank 0] time (ms) | fwd: 344.46 | bwd: 1535.69 | bwd_inner: 1449.97 | bwd_allreduce: 85.67 | step: 362.24
# [Rank 0] time (ms) | optimizer_allgather: 201.66 | optimizer_gradients: 26.31 | optimizer_step: 52.44
# [Rank 0] time (ms) | fwd_microstep: 343.53 | bwd_microstep: 1533.81 | bwd_inner_microstep: 1447.17 | bwd_allreduce_microstep: 86.56 | step_microstep: 363.36
# [Rank 0] time (ms) | fwd: 343.51 | bwd: 1533.82 | bwd_inner: 1447.17 | bwd_allreduce: 86.60 | step: 363.37
# [Rank 0] time (ms) | optimizer_allgather: 201.27 | optimizer_gradients: 26.18 | optimizer_step: 52.45
# [Rank 0] time (ms) | fwd_microstep: 343.37 | bwd_microstep: 1544.99 | bwd_inner_microstep: 1463.90 | bwd_allreduce_microstep: 81.02 | step_microstep: 362.58
# [Rank 0] time (ms) | fwd: 343.36 | bwd: 1545.00 | bwd_inner: 1463.90 | bwd_allreduce: 81.04 | step: 362.61
# [Rank 0] time (ms) | optimizer_allgather: 201.43 | optimizer_gradients: 26.26 | optimizer_step: 52.41
# [Rank 0] time (ms) | fwd_microstep: 50.10 | bwd_microstep: 587.72 | bwd_inner_microstep: 511.77 | bwd_allreduce_microstep: 75.85 | step_microstep: 362.74
# [Rank 0] time (ms) | fwd: 50.09 | bwd: 587.73 | bwd_inner: 511.79 | bwd_allreduce: 75.84 | step: 362.75
# --- Starting evaluation ---
# Computing metrics...
# **Final Test Accuracy: 83.41%**
# --- [Rank 1] Run complete ---
# wandb: ⢿ uploading artifact run-yknwyj7v-confusion_matrix_table (1.3s)
# wandb: ⣻ uploading artifact run-yknwyj7v-confusion_matrix_table (1.3s)
# wandb: ⣽ uploading artifact run-yknwyj7v-confusion_matrix_table (1.3s)
# wandb: ⣾ uploading artifact run-yknwyj7v-confusion_matrix_table (1.3s)
# wandb: ⣷ uploading artifact run-yknwyj7v-confusion_matrix_table (1.3s)
# wandb:
# wandb: ⣷ uploading artifact run-yknwyj7v-confusion_matrix_table (1.3s)
# wandb:
# wandb: Run history:
# wandb: System/Memory_Allocated_GB ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:             avg_train_loss ▁
# wandb:                      epoch ▁
# wandb:         epoch_duration_sec ▁
# wandb:        final_test_accuracy ▁
# wandb:                  step_loss █▇▇▆▆▅▅▅▅▅▄▄▃▄▄▄▃▄▄▃▃▄▃▃▂▂▃▂▃▂▂▂▁▂▂▂▁▁▁▁
# wandb:    total_training_time_sec ▁
# wandb:
# wandb: Run summary:
# wandb:     Performance/Throughput deepspeed.utils.time...
# wandb: System/Memory_Allocated_GB 5.06879
# wandb:             avg_train_loss 1.96421
# wandb:                      epoch 1
# wandb:         epoch_duration_sec 5320.1023
# wandb:        final_test_accuracy 83.41386
# wandb:                  step_loss 1.09766
# wandb:    total_training_time_sec 5320.1025
# wandb:
# wandb: 🚀 View run DeepSpeed-Stage2-ViT-Huge-Food101-2xT4-MBS16-GAS1-Batch-size-16-per-gpu at: https://wandb.ai/siddpath-university-of-maryland/Distributed%20ViT%20training%20systems-Latest_run/runs/yknwyj7v
# wandb: ⭐️ View project at: https://wandb.ai/siddpath-university-of-maryland/Distributed%20ViT%20training%20systems-Latest_run
# wandb: Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20251124_005650-yknwyj7v/logs
# --- [Rank 0] Run complete ---
# [2025-11-24 02:30:48,756] [INFO] [launch.py:367:main] Process 512 exits successfully.
# [2025-11-24 02:30:51,756] [INFO] [launch.py:367:main] Process 511 exits successfully.

# %% [markdown]
# ## Script for DeepSpeed Full Fine-Tune, running on 2 T4 gpus stage 3

# %%
# %%writefile deepspeed_config_stage3_vit_huge_bs16.json
# {
#     "fp16": {
#         "enabled": true,
#         "loss_scale": 0,
#         "loss_scale_window": 1000
#     },
#     "optimizer": {
#         "type": "AdamW",
#         "params": {
#             "lr": 5e-5,
#             "betas": [0.9, 0.999],
#             "eps": 1e-8,
#             "weight_decay": 3e-7
#         }
#     },
#     "zero_optimization": {
#         "stage": 3,
#         "allgather_partitions": true,
#         "allgather_bucket_size": 5e8,
#         "reduce_scatter": true,
#         "reduce_bucket_size": 5e8,
#         "overlap_comm": true,
#         "contiguous_gradients": true
#     },
#     "train_batch_size": 32,
#     "train_micro_batch_size_per_gpu": 16,
#     "gradient_accumulation_steps": 1,
#     "gradient_clipping": 1.0,
#     "steps_per_print": 50,
#     "wall_clock_breakdown": true,
#     "flops_profiler": {
#         "enabled": true,
#         "profile_step": 5,
#         "module_depth": -1,
#         "top_modules": 1,
#         "detailed": true,
#         "output_file": null
#     }
# }
# Out:
# Writing deepspeed_config_stage3_vit_huge_bs16.json

# %%
# %%writefile train_deepspeed_stage3_vit_huge_bs16.py
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from transformers import ViTForImageClassification, ViTImageProcessor
import deepspeed
import warnings
import wandb
import os
import time
import torch.distributed as dist
from torch.utils.data.distributed import DistributedSampler
from sklearn.metrics import confusion_matrix
import torch.profiler # <--- PRO ADDITION

# Suppress warnings
warnings.filterwarnings("ignore")
print("--- Initializing DEEPSPEED ZeRO Stage 3 (PRO RUN - SYSTEMS CHECK) ---")

# --- 1. DDP/DeepSpeed Setup ---
local_rank = int(os.environ['LOCAL_RANK'])
rank = int(os.environ['RANK'])
world_size = int(os.environ['WORLD_SIZE'])

torch.cuda.set_device(local_rank)
print(f"[Rank {rank}] Initializing process...")

# --- HELPER: PROVE ACTIVE SHARDING ---
def inspect_model_sharding(model):
    """Stage 3 should show ACTIVE parameter sharding"""
    if rank == 0:
        print(f"\n[Rank {rank}] --- INSPECTING SHARDING (Stage 3) ---")
        count = 0
        for name, param in model.named_parameters():
            # Check for DeepSpeed Attributes indicating sharding
            if hasattr(param, "ds_numel"):
                logical = param.ds_numel # Full size
                physical = param.numel() # Actual size on this GPU
                ratio = physical / logical
                print(f"Param: {name}")
                print(f"  Logical (Full):   {param.ds_shape} ({logical:,})")
                print(f"  Physical (Shard): {param.shape} ({physical:,})")
                print(f"  Shard Ratio:      {ratio:.2%} (Target: ~{100/world_size:.1f}%)")
                print("-" * 40)
                count += 1
            if count >= 2: break
        print("----------------------------------\n")

# --- 2. Model Setup (ViT-Huge, NO FREEZING) ---
if rank == 0:
    print("Loading pre-trained ViT-Huge model for full fine-tuning...")
model = ViTForImageClassification.from_pretrained('google/vit-huge-patch14-224-in21k', num_labels=101, ignore_mismatched_sizes=True)
print(f"[Rank {rank}] Model loaded.")

# --- !! KEEPING GRADIENT CHECKPOINTING !! ---
print("Enabling gradient checkpointing...")
model.gradient_checkpointing_enable()

# --- 3. DeepSpeed Initialization ---
if rank == 0:
    print("Initializing DeepSpeed...")
model_engine, optimizer, _, _ = deepspeed.initialize(
    model=model,
    model_parameters=model.parameters(), 
    config_params='deepspeed_config_stage3_vit_huge_bs16.json' # <-- USE PRO CONFIG
)
if rank == 0:
    print(f"DeepSpeed engine initialized. Training {sum(p.numel() for p in model_engine.module.parameters() if p.requires_grad):,} parameters.")

# --- 4. Data Prep (Food-101) ---
if rank == 0:
    print("Setting up data transformations...")
processor = ViTImageProcessor.from_pretrained('google/vit-huge-patch14-224-in21k')
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std)
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std)
])

if rank == 0:
    print("Loading Food-101 dataset...")
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=True, transform=train_transform)
    testset = torchvision.datasets.Food101(root='./data', split="test", download=True, transform=test_transform)
    
dist.barrier() 

if rank != 0:
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=False, transform=train_transform)
    testset = torchvision.datasets.Food101(root='./data', split="test", download=False, transform=test_transform)

# --- 5. Data Samplers ---
MICRO_BATCH_SIZE = 16 
train_sampler = DistributedSampler(trainset, num_replicas=world_size, rank=rank, shuffle=True)
test_sampler = DistributedSampler(testset, num_replicas=world_size, rank=rank, shuffle=False)
train_loader = DataLoader(trainset, batch_size=MICRO_BATCH_SIZE, sampler=train_sampler, num_workers=2, pin_memory=True)
test_loader = DataLoader(testset, batch_size=MICRO_BATCH_SIZE, sampler=test_sampler, num_workers=2, pin_memory=True)

# --- 6. WANDB INITIALIZATION ---
if rank == 0:
    wandb.init(
        project="Distributed ViT training systems-Latest_run",
        name="DeepSpeed-Stage3-ViT-Huge-Food101-2xT4-BS16-GC-Batch-size-16-per-gpu",
        config={ 
            "model": "vit-huge", 
            "optimization": "DeepSpeed ZeRO Stage 3 (GC)",
            "batch_size": MICRO_BATCH_SIZE * world_size
        }
    )

# PRO CHECK: Verify Sharding
inspect_model_sharding(model_engine.module)

# --- 7. DeepSpeed Training Loop ---
device = model_engine.device
num_epochs = 1
if rank == 0:
    print(f"--- Starting training for {num_epochs} epoch ---")
start_time = time.time()

for epoch in range(num_epochs):
    model_engine.train()
    train_sampler.set_epoch(epoch)
    total_loss_rank = 0.0
    
    for i, batch in enumerate(train_loader):
        # Optional: Break early for profiling if you don't want full epoch
        # if i >= 10: break 
        
        # LABEL 0: Top Level
        with torch.profiler.record_function(f"## Training Step {i} ##"):
            inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device)

            # LABEL 1: Forward Pass
            # EXPECTATION: Pink AllGather bars INSIDE this block (Overlap)
            with torch.profiler.record_function("## Forward Pass ##"):
                outputs = model_engine(inputs, labels=labels)
                loss = outputs.loss

            # LABEL 2: Backward Pass
            # EXPECTATION: Pink AllGather bars INSIDE this block (Overlap)
            with torch.profiler.record_function("## Backward Pass ##"):
                model_engine.backward(loss)

            # LABEL 3: Optimizer
            with torch.profiler.record_function("## Optimizer Step ##"):
                model_engine.step()

            total_loss_rank += loss.item()
            
            # --- PRO LOGGING ---
            if rank == 0:
                # 1. Log Loss
                wandb.log({"step_loss": loss.item()})
                
                # 2. Log System Stats (Every step or every few steps)
                if i % 10 == 0:
                    mem = torch.cuda.memory_allocated() / 1e9
                    # DeepSpeed tracks throughput internally via tput_timer
                    if hasattr(model_engine, 'tput_timer'):
                        tput = model_engine.tput_timer.avg_samples_per_sec
                    else:
                        tput = 0
                    
                    wandb.log({
                        "System/Memory_Allocated_GB": mem,
                        "Performance/Throughput": tput
                    })
                    print(f"  Epoch 1, Step {i}: Loss = {loss.item():.4f} | Mem: {mem:.2f}GB")

    # Sync Loss for epoch average
    total_loss_all_ranks = torch.tensor(total_loss_rank, dtype=torch.float, device=device)
    dist.all_reduce(total_loss_all_ranks, op=dist.ReduceOp.SUM)
    
    if rank == 0:
        avg_train_loss = total_loss_all_ranks.item() / (len(train_loader) * world_size)
        epoch_end_time = time.time()
        epoch_duration = epoch_end_time - start_time
        print(f"**Epoch 1/{num_epochs} - Avg. Training Loss: {avg_train_loss:.4f} (Duration: {epoch_duration:.2f}s)**")
        wandb.log({"epoch": 1, "avg_train_loss": avg_train_loss, "epoch_duration_sec": epoch_duration})

if rank == 0:
    total_time = time.time() - start_time
    wandb.log({"total_training_time_sec": total_time})

# --- 8. Evaluation ---
if rank == 0:
    print("--- Starting evaluation ---")
model_engine.eval()
rank_preds = []
rank_labels = []

with torch.no_grad():
    for batch in test_loader:
        inputs, labels = batch
        inputs = inputs.to(device)
        labels_cpu = labels.cpu() 
        outputs = model_engine(inputs)
        _, predicted = torch.max(outputs.logits.data, 1)
        rank_preds.extend(predicted.cpu().numpy())
        rank_labels.extend(labels_cpu.numpy())

all_preds = [None] * world_size
all_labels = [None] * world_size
dist.all_gather_object(all_preds, rank_preds)
dist.all_gather_object(all_labels, rank_labels)

if rank == 0:
    print("[Rank 0] All results gathered. Computing final accuracy...")
    flat_preds = [item for sublist in all_preds for item in sublist]
    flat_labels = [item for sublist in all_labels for item in sublist]
    
    correct = (torch.tensor(flat_preds) == torch.tensor(flat_labels)).sum().item()
    accuracy = 100 * correct / len(flat_preds)
    print(f"**Final Test Accuracy: {accuracy:.2f}%**")

    wandb.log({"final_test_accuracy": accuracy})
    class_names = trainset.classes
    wandb_cm = wandb.plot.confusion_matrix(
        preds=flat_preds, y_true=flat_labels, class_names=class_names
    )
    wandb.log({"confusion_matrix": wandb_cm})
    wandb.finish()

print(f"--- [Rank {rank}] Run complete ---")
# Out:
# Writing train_deepspeed_stage3_vit_huge_bs16.py

# %%
# !deepspeed --num_gpus=2 train_deepspeed_stage3_vit_huge_bs16.py
# Out:
# 2025-11-24 02:31:05.280645: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763951465.304501     773 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763951465.312573     773 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [2025-11-24 02:31:10,817] [WARNING] [runner.py:232:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2025-11-24 02:31:10,817] [INFO] [runner.py:630:main] cmd = /usr/bin/python3 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMV19 --master_addr=127.0.0.1 --master_port=29500 --enable_each_rank_log=None --log_level=info train_deepspeed_stage3_vit_huge_bs16.py
# 2025-11-24 02:31:18.356307: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763951478.380291     825 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763951478.387193     825 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [2025-11-24 02:31:23,427] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_DEV_PACKAGE=libnccl-dev=2.22.3-1+cuda12.5
# [2025-11-24 02:31:23,428] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_DEV_PACKAGE_VERSION=2.22.3-1
# [2025-11-24 02:31:23,428] [INFO] [launch.py:155:main] 0 NCCL_VERSION=2.22.3-1
# [2025-11-24 02:31:23,428] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_DEV_PACKAGE_NAME=libnccl-dev
# [2025-11-24 02:31:23,428] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_PACKAGE=libnccl2=2.22.3-1+cuda12.5
# [2025-11-24 02:31:23,428] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_PACKAGE_NAME=libnccl2
# [2025-11-24 02:31:23,428] [INFO] [launch.py:155:main] 0 NV_LIBNCCL_PACKAGE_VERSION=2.22.3-1
# [2025-11-24 02:31:23,428] [INFO] [launch.py:162:main] WORLD INFO DICT: {'localhost': [0, 1]}
# [2025-11-24 02:31:23,428] [INFO] [launch.py:168:main] nnodes=1, num_local_procs=2, node_rank=0
# [2025-11-24 02:31:23,428] [INFO] [launch.py:179:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1]})
# [2025-11-24 02:31:23,428] [INFO] [launch.py:180:main] dist_world_size=2
# [2025-11-24 02:31:23,428] [INFO] [launch.py:184:main] Setting CUDA_VISIBLE_DEVICES=0,1
# [2025-11-24 02:31:23,429] [INFO] [launch.py:272:main] process 877 spawned with command: ['/usr/bin/python3', '-u', 'train_deepspeed_stage3_vit_huge_bs16.py', '--local_rank=0']
# [2025-11-24 02:31:23,429] [INFO] [launch.py:272:main] process 878 spawned with command: ['/usr/bin/python3', '-u', 'train_deepspeed_stage3_vit_huge_bs16.py', '--local_rank=1']
# 2025-11-24 02:31:28.685820: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763951488.708050     877 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763951488.715411     877 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-24 02:31:28.719019: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763951488.740939     878 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763951488.747694     878 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# --- Initializing DEEPSPEED ZeRO Stage 3 (PRO RUN - SYSTEMS CHECK) ---
# [Rank 0] Initializing process...
# Loading pre-trained ViT-Huge model for full fine-tuning...
# --- Initializing DEEPSPEED ZeRO Stage 3 (PRO RUN - SYSTEMS CHECK) ---
# [Rank 1] Initializing process...
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-huge-patch14-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Rank 0] Model loaded.
# Enabling gradient checkpointing...
# Initializing DeepSpeed...
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-huge-patch14-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Rank 1] Model loaded.
# Enabling gradient checkpointing...
# Parameter Offload - Persistent parameters statistics: param_count = 325, numel = 537701

# %% [markdown]
# ## Profiling of the processes

# %% [markdown]
# ### Script for DeepSpeed Full Fine-Tune, running on 2 T4 gpus stage 2

# %%
# %%writefile train_deepspeed_stage2_profiler.py
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from transformers import ViTForImageClassification, ViTImageProcessor
import deepspeed
import warnings
import os
import torch.distributed as dist
from torch.utils.data.distributed import DistributedSampler
import torch.profiler # Import Profiler

# Suppress warnings
warnings.filterwarnings("ignore")
print("--- Initializing DEEPSPEED ZeRO Stage 2 (PROFILING RUN - LABELED) ---")

# --- 1. DDP/DeepSpeed Setup ---
local_rank = int(os.environ['LOCAL_RANK'])
rank = int(os.environ['RANK'])
world_size = int(os.environ['WORLD_SIZE'])

torch.cuda.set_device(local_rank)

# --- 2. Model Setup (ViT-Huge) ---
if rank == 0:
    print("Loading pre-trained ViT-Huge model...")
model = ViTForImageClassification.from_pretrained('google/vit-huge-patch14-224-in21k', num_labels=101, ignore_mismatched_sizes=True)

# Enable Gradient Checkpointing
model.gradient_checkpointing_enable()

# --- 3. DeepSpeed Initialization ---
model_engine, optimizer, _, _ = deepspeed.initialize(
    model=model,
    model_parameters=model.parameters(), 
    config_params='deepspeed_config_stage2_vit_huge_bs16.json'
)

# --- 4. Data Prep (Food-101) ---
processor = ViTImageProcessor.from_pretrained('google/vit-huge-patch14-224-in21k')
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std)
])

if rank == 0:
    print("Loading dataset...")
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=True, transform=train_transform)
dist.barrier()
if rank != 0:
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=False, transform=train_transform)

# --- 5. Data Samplers ---
MICRO_BATCH_SIZE = 16 
train_sampler = DistributedSampler(trainset, num_replicas=world_size, rank=rank, shuffle=True)
train_loader = DataLoader(trainset, batch_size=MICRO_BATCH_SIZE, sampler=train_sampler, num_workers=2, pin_memory=True)

# --- 6. Define Profiler Handler ---
def trace_handler(prof):
    if rank == 0:
        print("Profiler trace ready. Saving to ./logs/stage2_trace ...")
        os.makedirs("./logs/stage2_trace", exist_ok=True)
        prof.export_chrome_trace(f"./logs/stage2_trace/rank{rank}_trace.json")
        print("Trace saved.")

# --- 7. Training Loop with Profiler & LABELS ---
device = model_engine.device
model_engine.train()

print("Starting profiling run...")

# Short schedule: Wait 1, Warmup 1, Active 3 (Just enough to get clear data)
with torch.profiler.profile(
    schedule=torch.profiler.schedule(wait=1, warmup=1, active=3, repeat=1),
    on_trace_ready=trace_handler,
    record_shapes=True,
    with_stack=True
) as prof:

    for i, batch in enumerate(train_loader):
        # Stop early after the active phase
        if i >= 6:
            break

        # Create a top-level label for the whole step
        with torch.profiler.record_function(f"## Training Step {i} ##"):
            
            inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device)

            # --- LABEL 1: FORWARD PASS ---
            # In Stage 3, look for AllGather INSIDE this block.
            # In Stage 2, it should be clean (mostly compute).
            with torch.profiler.record_function("## Forward Pass ##"):
                outputs = model_engine(inputs, labels=labels)
                loss = outputs.loss

            # --- LABEL 2: BACKWARD PASS ---
            # In Stage 2, look for ReduceScatter at the END of this block (blocking).
            with torch.profiler.record_function("## Backward Pass ##"):
                model_engine.backward(loss)

            # --- LABEL 3: OPTIMIZER ---
            with torch.profiler.record_function("## Optimizer Step ##"):
                model_engine.step()

            if rank == 0:
                print(f"Step {i}: Loss = {loss.item():.4f}")

        # Step the profiler
        prof.step()

print("Profiling complete.")

# %%
# !deepspeed --num_gpus=2 train_deepspeed_stage2_profiler.py

# %% [markdown]
# ### Script for DeepSpeed Full Fine-Tune, running on 2 T4 gpus stage 3

# %%
# %%writefile train_deepspeed_stage3_profiler.py
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from transformers import ViTForImageClassification, ViTImageProcessor
import deepspeed
import warnings
import os
import torch.distributed as dist
from torch.utils.data.distributed import DistributedSampler
import torch.profiler # Import Profiler

# Suppress warnings
warnings.filterwarnings("ignore")
print("--- Initializing DEEPSPEED ZeRO Stage 3 (PROFILING RUN - LABELED) ---")

# --- 1. DDP/DeepSpeed Setup ---
local_rank = int(os.environ['LOCAL_RANK'])
rank = int(os.environ['RANK'])
world_size = int(os.environ['WORLD_SIZE'])

torch.cuda.set_device(local_rank)

# --- 2. Model Setup (ViT-Huge) ---
if rank == 0:
    print("Loading pre-trained ViT-Huge model...")
model = ViTForImageClassification.from_pretrained('google/vit-huge-patch14-224-in21k', num_labels=101, ignore_mismatched_sizes=True)

# Enable Gradient Checkpointing
model.gradient_checkpointing_enable()

# --- 3. DeepSpeed Initialization ---
# Note: Using Stage 3 Config
model_engine, optimizer, _, _ = deepspeed.initialize(
    model=model,
    model_parameters=model.parameters(), 
    config_params='deepspeed_config_stage3_vit_huge_bs16.json'
)

# --- 4. Data Prep (Food-101) ---
processor = ViTImageProcessor.from_pretrained('google/vit-huge-patch14-224-in21k')
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(224, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std)
])

if rank == 0:
    print("Loading dataset...")
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=True, transform=train_transform)
    
dist.barrier()

if rank != 0:
    trainset = torchvision.datasets.Food101(root='./data', split="train", download=False, transform=train_transform)

# --- 5. Samplers ---
MICRO_BATCH_SIZE = 16 
train_sampler = DistributedSampler(trainset, num_replicas=world_size, rank=rank, shuffle=True)
train_loader = DataLoader(trainset, batch_size=MICRO_BATCH_SIZE, sampler=train_sampler, num_workers=2, pin_memory=True)

# --- 6. Define Profiler Handler ---
def trace_handler(prof):
    if rank == 0:
        print("Profiler trace ready. Saving to ./logs/stage3_trace ...")
        os.makedirs("./logs/stage3_trace", exist_ok=True)
        prof.export_chrome_trace(f"./logs/stage3_trace/rank{rank}_trace.json")
        print("Trace saved.")

# --- 7. Training Loop with Profiler & LABELS ---
device = model_engine.device
model_engine.train()

print("Starting profiling run...")

with torch.profiler.profile(
    schedule=torch.profiler.schedule(wait=1, warmup=1, active=3, repeat=1),
    on_trace_ready=trace_handler,
    record_shapes=True,
    with_stack=True
) as prof:

    for i, batch in enumerate(train_loader):
        # Stop early! We only need enough steps for the schedule
        if i >= 6:
            break

        # Create a top-level label for the whole step
        with torch.profiler.record_function(f"## Training Step {i} ##"):

            inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device)

            # --- LABEL 1: FORWARD PASS ---
            # PROOF POINT: In Stage 3, you will see communication INSIDE this block
            with torch.profiler.record_function("## Forward Pass ##"):
                outputs = model_engine(inputs, labels=labels)
                loss = outputs.loss

            # --- LABEL 2: BACKWARD PASS ---
            # PROOF POINT: In Stage 3, you will see communication INSIDE this block
            with torch.profiler.record_function("## Backward Pass ##"):
                model_engine.backward(loss)

            # --- LABEL 3: OPTIMIZER ---
            with torch.profiler.record_function("## Optimizer Step ##"):
                model_engine.step()

            if rank == 0:
                print(f"Step {i}: Loss = {loss.item():.4f}")

        # Step the profiler
        prof.step()

print("Profiling complete.")

# %%
# !deepspeed --num_gpus=2 train_deepspeed_stage3_profiler.py

# %% [markdown]
# ### checking the results

# %%
# !pip install -q tensorboard

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./logs

# %%
# %tensorboard --logdir ./logs

# %%
# !pkill tensorboard

# %%
# !zip -r my_profiler_logs.zip ./logs
